# %% [markdown]
# # Thermal stability of hundreds of point mutants of a family 1 glycoside hydrolase

# %% [markdown]
# Here, we are determining the thermal stability of about a hundred and fifty point mutants of BglB (model based on 2JIE). After automated mutagensis of the BglB coding sequence, protein production, and protein purification, each mutant's activity at 100 mM pNPG at pH 7.4 at a range of temperatures from 30 C to 50 C was measured using the rate of formation of the pNPG hydrolysis product p-nitrophenol.
#
# Data were collected into a table with the columns `well`, `rate`, and `mutant` using Google Docs and exported to CSV, which is the input file here.
#
# ## Data input and cleanup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
from scipy.optimize import curve_fit 
from numpy import log, exp, linspace, sqrt, diag
from sklearn.linear_model import LinearRegression
import os
import re 

df = pandas.read_csv( 'data/data_2016_03_09.csv' )
raw = len( df )
df.index = df.mutant
df.drop( 'mutant', inplace=True )
df.drop( ['WT', 'WT1'], inplace=True )
df.dropna( inplace=True ) 

with open( 'data/allowed_mutants.txt' ) as fn:
    mutants = [ i.split('.')[0].upper() for i in fn.readlines() if len( i ) > 1 ]
    
def is_good( name ):
    return name in mutants 

# this is a sanity-checking routine for "off-by-threes"
# let's just rename all the tubes
not_allowed = []
l = []
for name in df.index:
    #print name
    if is_good( name ):
        l.append( name )
    else:
        new = name[0] + str( int( re.findall( r'\d+', name )[0] ) - 3 ) + name[-1]
        if is_good( new ):
            l.append( new )
        else:
            l.append( 'drop_me' )
            not_allowed.append( name )
            
assert len( df.index ) == len( l ) # do not want to reindex wrongly! 
df.index = l
df.mutant = df.index 
df.drop( ['drop_me'], inplace=True )

# temperature keys as CSV files in data/
temp_key = pandas.read_csv( 'data/temp_key.csv' )
temp_key.index = temp_key.Well
df['temp'] = df.well.str[0].map( temp_key.Celsius.to_dict() ) 
df.dropna( inplace=True )
pos_and_neg = len( df )
df = df[( df.rate > 0 )]
df.sample( 10 )

# diagnostics 
print 'Input has {} rates. {} will be used, {} will be dropped because of mutant name, {} because negative).'.format( raw, len( df ), raw - pos_and_neg , pos_and_neg - len( df ) ), 
print 'Samples {} were dropped because the given native residue does not match the BglB sequence and is not off by three'.format( set( not_allowed ) )
# Out:
# Input has 3048 rates. 2350 will be used, 48 will be dropped because of mutant name, 650 because negative). Samples set(['Q384R']) were dropped because the given native residue does not match the BglB sequence and is not off by three

# %%
# production and purification data 
pp = pandas.read_csv( 'data/Bagel Thermostability - Thermostability protein production progress.csv', index_col='mutant' )
pp.index.value_counts()

# this is a sanity-checking routine for "off-by-threes"
# let's just rename all the tubes
pp_not_allowed = []
l = []
pp.drop( [ 'WT', 'nan' ], axis=0, inplace=True ) 

from numpy import nan 

for name in pp.index: 
    if type( name ) == float:
        l.append( 'drop_me' ) 
    elif is_good( name ):
        l.append( name )
    else:
        new = name[0] + str( int( re.findall( r'\d+', name )[0] ) - 3 ) + name[-1]
        if is_good( new ):
            l.append( new )
        else:
            l.append( 'drop_me' )
            not_allowed.append( name )

pp.index = l
print len( pp )
# Out:
# 139

# %% [markdown]
# ## Determine protein parameters Tm and k
#
# To determine protein parameters Tm and k (steepness of melting curve), we will fit the cleaned data to the logistic equation. To determine starting parameters for the search algorithm `curve_fit`, we'll just fit a straight line to the data using SciKit-Learn's linear regression.

# %%
# logistic equation 
def f(x, x0, k): 
    return 1/(1+exp(-k*(x-x0)))

# util function to fit a mutant 
def fit( df ):
    name = df.mutant.unique()[0]
    df.rate = df.rate / df.rate.max()
    
    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]
    
    # try fitting to logistic eqn using approximate params from linear fit
    try:
        p0 = ( df.temp.mean(), slope )
        popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
        perr = sqrt( diag( pcov ) ) 
        if 30 < popt[0] < 50 and popt[1] < 0: # biological assay limits, and make sure k is the right sign
            return pandas.Series( popt, index=['tm', 'k'] )
        else:
            #iffy += [ name ]
            raise Exception( '{0} dropped because fitted Tm of {1:2.2f} is outside range 30-50 C'.format( name, popt[0] ) )
    except Exception as e:
        print e
    
grouped = df.groupby( by='mutant' )
fits = grouped.apply( fit )
print ''
print 'Successfully fit {} of {} samples to the logistic equation'.format( len( fits.dropna() ), len( grouped ) )
# Out:
# D403A dropped because fitted Tm of 17.05 is outside range 30-50 C
# E164A dropped because fitted Tm of 47.48 is outside range 30-50 C
# E164G dropped because fitted Tm of 20.99 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# F415A dropped because fitted Tm of -9.15 is outside range 30-50 C
# F415N dropped because fitted Tm of 35.98 is outside range 30-50 C
# G355A dropped because fitted Tm of 50.07 is outside range 30-50 C
# H119E dropped because fitted Tm of 98.16 is outside range 30-50 C
# H119N dropped because fitted Tm of 11.41 is outside range 30-50 C
# H178R dropped because fitted Tm of 40.61 is outside range 30-50 C
# H315N dropped because fitted Tm of 55.55 is outside range 30-50 C
# H379R dropped because fitted Tm of 32.13 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# M221A dropped because fitted Tm of 47.90 is outside range 30-50 C
# M323K dropped because fitted Tm of 54.77 is outside range 30-50 C
# N293A dropped because fitted Tm of 178.39 is outside range 30-50 C
# N293D dropped because fitted Tm of 54.12 is outside range 30-50 C
# N293Q dropped because fitted Tm of 23.07 is outside range 30-50 C
# Q19A dropped because fitted Tm of 201.35 is outside range 30-50 C
# Q19C dropped because fitted Tm of 15.36 is outside range 30-50 C
# R240D dropped because fitted Tm of 33.30 is outside range 30-50 C
# R240E dropped because fitted Tm of 53.20 is outside range 30-50 C
# S16N dropped because fitted Tm of 35.19 is outside range 30-50 C
# T296A dropped because fitted Tm of 88.07 is outside range 30-50 C
# W120A dropped because fitted Tm of 80.35 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# W34A dropped because fitted Tm of 26.12 is outside range 30-50 C
# W399A dropped because fitted Tm of 39.78 is outside range 30-50 C
# W399C dropped because fitted Tm of 37.42 is outside range 30-50 C
# W399G dropped because fitted Tm of 29.82 is outside range 30-50 C
# W399R dropped because fitted Tm of 51.98 is outside range 30-50 C
# W399S dropped because fitted Tm of 63.22 is outside range 30-50 C
# W407A dropped because fitted Tm of 54.67 is outside range 30-50 C
# W407Q dropped because fitted Tm of 35.20 is outside range 30-50 C
# W407R dropped because fitted Tm of 40.54 is outside range 30-50 C
# Y166P dropped because fitted Tm of 32.13 is outside range 30-50 C
# Y295A dropped because fitted Tm of 34.69 is outside range 30-50 C
# Y295G dropped because fitted Tm of 19.58 is outside range 30-50 C
#
# Successfully fit 79 of 117 samples to the logistic equation

# %%
fits
# Out:
#                tm         k
# mutant
# A192S   39.082601 -0.906304
# A356A   39.888266 -1.124698
# A357A   39.094581 -0.325209
# A408A   39.955931 -1.260729
# C167A   39.735604 -1.388447
# C167Q   38.471567 -0.529354
# D403A         NaN       NaN
# E154D   38.699104 -0.688686
# E164A         NaN       NaN
# E164G         NaN       NaN
# E164R         NaN       NaN
# E177A   37.307655 -0.486928
# E177K   36.649702 -0.666761
# E177L   39.223503 -0.520210
# E222A   36.743814 -0.656627
# E222H   34.708312 -0.636223
# E222K   38.526868 -0.464967
# E222Q   39.421645 -0.815422
# E222R   39.086509 -0.748890
# E222Y   37.041199 -0.593383
# E353A   43.259171 -0.093197
# E406A   39.934310 -1.524719
# E406D   40.554599 -0.926168
# E426S   39.459240 -1.449480
# F415A         NaN       NaN
# F415N         NaN       NaN
# F72H    38.606014 -0.415987
# G355A         NaN       NaN
# H101R   40.021708 -0.910848
# H119A   40.158045 -1.028931
# ...           ...       ...
# T218A   40.045653 -1.122531
# T296A         NaN       NaN
# T352A   38.027066 -0.745704
# V52G    39.206299 -1.005693
# W120A         NaN       NaN
# W120F   41.510527 -0.462998
# W120H   39.888395 -0.574204
# W325A   40.188242 -0.362363
# W325C   39.181842 -0.888861
# W325G         NaN       NaN
# W325H   37.032928 -0.009632
# W325L   30.523417 -0.135566
# W325R   39.873792 -0.713240
# W34A          NaN       NaN
# W399A         NaN       NaN
# W399C         NaN       NaN
# W399G         NaN       NaN
# W399R         NaN       NaN
# W399S         NaN       NaN
# W407A         NaN       NaN
# W407G   31.738916 -0.140748
# W407Q         NaN       NaN
# W407R         NaN       NaN
# W409Y   36.614921 -0.392453
# Y166P         NaN       NaN
# Y18A    37.172903 -0.346462
# Y294A   39.999766 -0.755361
# Y294F   33.776906 -0.175158
# Y295A         NaN       NaN
# Y295G         NaN       NaN
#
# [117 rows x 2 columns]

# %% [markdown]
# ## Diagnostic plots to help determine goodness of fits

# %%
#!mkdir plots 
for index, df in grouped:
    name = df.mutant.unique()[0]
    rate = df.rate / df.rate.max() 
    plt.figure( figsize=(2,2) )
    plt.scatter( df.temp, rate, alpha=0.7, color='black', marker='.' )
    popt = fits.loc[ name ]
    if popt is not None:
        x_space = linspace( df.temp.min(), df.temp.max(), 100 )
        plt.plot( x_space, f( x_space, *popt ), alpha=0.5, color='purple' )
    plt.xlabel( 'T (C)' )
    plt.ylabel( 'Normalized rate')
    plt.xticks( [ 30, 40, 50 ] )
    plt.yticks( [ 0, 0.5, 1 ] )
    plt.title( name )
    plt.tight_layout()
    plt.savefig( 'plots/%s.pdf' % name, format='pdf' )
    plt.show()
    plt.close()

# %%
# I looked at all the plots 

drop_list = [ 
    'E353A', 'H315E', 'M261D', 'P329N', 'Q313R', 'R76A', 'S16A', 
    'W325H', 'W325L', 'W407G', 'Y294F', 
]

from numpy import nan 

for drop in drop_list:
    fits.loc[ drop ] = ( nan, nan )

# %%
# add metadata
fits['native'] = fits.index.str[0]
fits['designed'] = fits.index.str[-1]
fits['position'] = fits.index.str[1:-1].astype( int )

fits.to_csv( 'data/mutants_fitted.csv' )

# %%
! wc -l data/mutants_fitted.csv
# Out:
#      118 data/mutants_fitted.csv

# %%
plos = pandas.read_csv( '/Users/alex/Documents/bagel-data/clean_data/clean_for_pandas.csv', index_col='name' )

# %%
all_data = pp.join( fits )
all_data = all_data.join( plos, rsuffix='PLOS' ) 
all_data.to_csv( 'data/all_data.csv' ) 

print all_data.columns

pub_cols = [
    'norm_y', 
    'protein_on_gel', 'why_no_tm', 'in_plos_paper', 
    'tm', 'k', 
    'native', 'designed', 'position', 
    'kcat', 'km', 'kcatkm', 'yPLOS', 
]

#all_data.sort_values( 'position' )  
pub = all_data[ pub_cols ].sort_values( 'position' )  
pub.to_csv( 'data/pub_data.csv' ) 
pub.head( 5 )
# Out:
# Index([u'idx', u'Unnamed: 1', u'student', u'date_transform', u'img_url',
#        u'colonies', u'grow_weight', u'expr_weight', u'beads', u'y', u'norm_y',
#        u'gel_img_exists', u'protein_on_gel', u'assay_data_exists',
#        u'tm_exists', u'why_no_tm', u'in_plos_paper', u'tm', u'k', u'native',
#        u'designed', u'position', u'yPLOS', u'km', u'ekm', u'kcat', u'ekcat',
#        u'ki', u'eki', u'kcatkm', u'ekcatkm'],
#       dtype='object')
#       norm_y  protein_on_gel why_no_tm  in_plos_paper         tm         k  \
# S14A     NaN             1.0       NaN              1  40.017869 -1.565036
# T15A    0.62             1.0       NaN            NaN  38.696923 -0.457046
# S16A    1.01             1.0       NaN              1        NaN       NaN
# S16A    0.89             1.0       NaN              1        NaN       NaN
# S16N    0.18             0.5       NaN            NaN        NaN       NaN
#
#      native designed  position  kcat     km  kcatkm  yPLOS
# S14A      S        A        14   320   8.25   38823   0.60
# T15A      T        A        15   NaN    NaN     NaN    NaN
# S16A      S        A        16   154  14.01   10997   0.83
# S16A      S        A        16   154  14.01   10997   0.83
# S16N      S        N        16   NaN    NaN     NaN    NaN

# %%
# heatmap

import pandas 
from sklearn.preprocessing import scale
from numpy import array, log, ma, isnan
# %matplotlib inline
import matplotlib.pyplot as plt

df = pandas.read_csv( 'data/pub_data.csv', index_col=0 )
df['s_tm'] = ( df.tm - 39.5 ) 
df['s_kcat'] = log( df.kcat / 800 ) 
df['s_km'] = log( df.km / 5 ) 
df['s_kcatkm'] = log( df.kcatkm / 174800 ) 

a = array( [ df.protein_on_gel, df.s_tm, df.s_kcat, df.s_km, df.s_kcatkm ] ).T 

plt.figure( figsize=( 1.1, 32 ) ) 
plt.imshow( a, interpolation='none' ) 
plt.yticks( range( len( df.index ) ), df.index )

# value labels 
cols = [ 'Expression', '$T_M$', '$k_{cat}$', '$K_M$', '$k_{cat}/K_M$' ] 
plt.xticks( range( len( cols ) + 1 ), cols ) 
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)

# remove border
# Out:
# [None, None, None, None, None, None]

# %%
from numpy import linspace
a = [ linspace( -5, 5, 9 ), linspace( 5, -5, 9) ] 

plt.imshow( a, interpolation='none', cmap='viridis' )

# %%
color_map = {
    -4: 'rgba(77, 0, 85, 1)', 
    -3: 'rgba(79, 22, 125, 1)',
    
    
    0: 'rgba( 0, 150, 141, 1 )', 
}

# %%
# join together the fits and the production dfs 

j = fits.join( pp ) 
j.sample( 20 )

print j.columns 

# clean the dataframe 

jcols = [ 
    'beads', 'y', 'protein_on_gel', 'in_plos_paper', 
    'native', 'designed', 'position', 'tm', 'k', 
]

jj = j[ jcols ] 
jj = jj.dropna()
len ( jj )
# Out:
# Index([u'tm', u'k', u'native', u'designed', u'position', u'idx', u'Unnamed: 1',
#        u'student', u'date_transform', u'img_url', u'colonies', u'grow_weight',
#        u'expr_weight', u'beads', u'y', u'norm_y', u'gel_img_exists',
#        u'protein_on_gel', u'assay_data_exists', u'tm_exists', u'why_no_tm',
#        u'in_plos_paper'],
#       dtype='object')
# 53

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ed13e7ee8914> in <module>()
# ----> 1 tms = fits[(fits.tm > 0)].tm - 39.5
#       2 from numpy import array
#       3
#       4 a = array( [tms, tms] ).T
#       5 plt.figure( figsize=( 1, 20 ) )
#
# NameError: name 'fits' is not defined

# %%
# makes resfiles for DDG Rosetta app 
#!mkdir ddg/resfiles 

for ( index, series ) in fits.iterrows():
    with open( 'ddg/resfiles/{}'.format( index ), 'w' ) as fn:
        fn.write( 'NATRO\nSTART\n{} A PIKAA {}'.format( series.position, series.designed ) )

# %%
# %%bash
# # this will run the Rosetta app `ddg_monomer` on all the mutants in `fits`, above
#
# ls ddg/resfiles > ddg/list
# NUM=$( wc -l ddg/list | cut -d' ' -f1 )
# cd ddg && echo sbatch --array=1-${NUM} sub.sh
# Out:
# sbatch --array=1- sub.sh

# %% [markdown]
# ## Comparison between Rosetta `ddg_monomer` app and experimental results

# %%
! ( head -1 ddg/ddg_predictions.out && grep -v desc ddg/ddg_predictions.out ) > ddg/readable_output
! head ddg/readable_output
# Out:
# ddG: description total fa_atr fa_rep fa_sol fa_intra_rep fa_elec pro_close hbond_sr_bb hbond_lr_bb hbond_bb_sc hbond_sc dslf_fa13 coordinate_constraint angle_constraint dihedral_constraint rama omega fa_dun p_aa_pp ref chainbreak res_type_constraint
# ddG: H101R     3.084     3.550    -0.581    -4.436    -0.003     4.233    -0.054    -0.086    -0.144     1.662     0.136    -0.005     0.000     0.000     0.000    -0.183    -0.359    -0.144     0.005    -0.507     0.000     0.000
#
# ddG: P180K     9.735    -1.373     0.225     7.052     0.030     0.413     0.109    -0.026     0.362     0.637     1.134    -0.002     0.000     0.000     0.000     0.279    -0.092     0.977     0.079    -0.068     0.000     0.000
#
# ddG: H379T     4.029    10.145    -0.503    -3.892    -0.020     0.473     0.061    -0.218     0.286    -1.205     2.150    -0.005     0.000     0.000     0.000     0.331     0.421    -3.625    -0.176    -0.193     0.000     0.000
#
# ddG: Y75H     3.305     1.674    -2.389     1.336    -0.023     0.777    -0.018    -0.230    -0.196     0.143     1.862     0.001     0.000     0.000     0.000     0.129     0.525    -0.301    -0.211     0.226     0.000     0.000
#
# ddG: L122E     5.403    -1.551    -0.613    11.396     0.023    -3.202     0.043    -0.091    -0.065    -0.546    -3.184    -0.001     0.000     0.000     0.000    -0.167    -0.334     5.518     0.335    -2.156     0.000     0.000

# %%
preds = pandas.read_csv( 'ddg/readable_output', sep='\s+' )
preds.index = preds.description.values
joined = preds.join( jj )
joined
# Out:
#        ddG: description   total  fa_atr  fa_rep  fa_sol  fa_intra_rep  \
# C167Q  ddG:       C167Q   7.123   4.771   0.167  -7.495         0.008
# C167Q  ddG:       C167Q   3.917  -9.104   3.124   5.132         0.000
# D403A  ddG:       D403A  -0.084   8.162  -2.992 -11.071        -0.024
# D403A  ddG:       D403A  -0.037   5.611  -0.695 -10.098        -0.010
# D55G   ddG:        D55G  -5.800   2.399   0.108  -5.663        -0.008
# D55G   ddG:        D55G  -2.896   2.002   0.558  -5.176        -0.022
# E154D  ddG:       E154D   5.108  -4.377   0.348   1.037        -0.007
# E154D  ddG:       E154D   1.733   2.605   0.279  -1.832         0.018
# E164A  ddG:       E164A   1.246  11.627  -1.906 -13.616        -0.085
# E164A  ddG:       E164A  -3.223   7.296  -1.810 -10.824         0.003
# E177A  ddG:       E177A  -0.731   1.029  -0.495  -3.457        -0.024
# E177A  ddG:       E177A  -0.361   7.804  -1.012 -10.885         0.003
# E406D  ddG:       E406D  10.201  -0.375  -0.568   0.573         0.011
# E406D  ddG:       E406D   1.322   6.610  -0.407  -7.735         0.006
# E426S  ddG:       E426S  -3.236  -1.003  -0.263   4.655        -0.008
# E426S  ddG:       E426S  -0.222  -0.024   1.390  -0.187        -0.009
# G174R  ddG:       G174R  13.066 -10.880   4.472  15.257         0.061
# G174R  ddG:       G174R  18.259  -7.393   5.560  10.213         0.047
# G22S   ddG:        G22S   2.216  -2.363   5.302   1.628         0.010
# G22S   ddG:        G22S   8.951  -3.006   5.576   2.627        -0.016
# H101R  ddG:       H101R   3.084   3.550  -0.581  -4.436        -0.003
# H101R  ddG:       H101R   0.543   3.462  -0.754  -0.705         0.010
# H178R  ddG:       H178R   0.562  -0.355   0.413   7.517         0.108
# H178R  ddG:       H178R   2.399  -3.592  -0.635  10.348         0.132
# H223G  ddG:       H223G   0.613   9.372  -2.140  -2.830         0.017
# H223G  ddG:       H223G   5.618  14.442  -1.874 -11.092         0.021
# H315N  ddG:       H315N   5.300   3.977  -0.244  -4.216         0.017
# H315N  ddG:       H315N   0.095   1.303  -0.243  -0.376         0.016
# H328C  ddG:       H328C  -2.408  10.578  -0.731 -10.742        -0.019
# H328C  ddG:       H328C  -0.766   3.783   0.948  -2.596         0.012
# ...     ...         ...     ...     ...     ...     ...           ...
# W120A  ddG:       W120A   7.079  19.364  -4.741  -7.961        -0.037
# W120A  ddG:       W120A   4.122  20.385  -5.606  -8.105        -0.036
# W120F  ddG:       W120F   1.691   6.595  -3.799  -4.736        -0.006
# W120F  ddG:       W120F  -1.773   5.915  -3.021  -4.014        -0.008
# W247N  ddG:       W247N   7.820  11.106  -3.131   0.168        -0.026
# W247N  ddG:       W247N   8.209  14.747  -0.432  -4.167        -0.024
# W325L  ddG:       W325L   5.585  16.415  -2.039 -11.910         0.164
# W325L  ddG:       W325L   5.549  17.186  -1.460 -12.269         0.150
# W34A   ddG:        W34A   8.512  21.478  -3.590  -6.014        -0.017
# W34A   ddG:        W34A   9.688  16.985  -0.915  -4.455        -0.040
# W399C  ddG:       W399C   4.282  16.451  -1.498  -5.500        -0.028
# W399C  ddG:       W399C   7.645  15.670   0.048  -9.383        -0.050
# W399S  ddG:       W399S   9.946  12.606   0.185  -4.508        -0.048
# W399S  ddG:       W399S   5.103  19.739  -1.347 -10.282        -0.025
# W407C  ddG:       W407C  11.852  17.714  -3.185  -6.711         0.034
# W407C  ddG:       W407C   7.936  18.149  -2.554  -7.410        -0.038
# W407G  ddG:       W407G   5.351  20.957  -3.000 -10.517        -0.024
# W407G  ddG:       W407G   7.485  16.196  -2.838  -4.310        -0.037
# W407R  ddG:       W407R  12.019   5.413  -0.969   5.741        -0.028
# W407R  ddG:       W407R   7.325  10.600  -2.459   0.372        -0.031
# Y166D  ddG:       Y166D   8.362   4.285   0.637   4.117        -0.046
# Y166D  ddG:       Y166D   4.113   0.855  -2.694  12.115         0.003
# Y294A  ddG:       Y294A   8.613  15.448  -1.033  -5.825        -0.055
# Y294A  ddG:       Y294A   6.037  14.635  -0.395  -5.779        -0.032
# Y295A  ddG:       Y295A  13.060  12.999  -1.798  -9.511         0.010
# Y295A  ddG:       Y295A  10.874  18.604  -3.099 -14.807        -0.003
# Y75H   ddG:        Y75H   3.305   1.674  -2.389   1.336        -0.023
# Y75H   ddG:        Y75H   5.061   3.859  -0.733   1.711        -0.011
# Y75H   ddG:        Y75H   6.024   5.259  -1.593  -0.733        -0.010
# Y75H   ddG:        Y75H   4.991   1.300  -0.293   1.974        -0.025
#
#        fa_elec  pro_close  hbond_sr_bb    ...     res_type_constraint  beads  \
# C167Q    4.185      0.097       -0.174    ...                       0      1
# C167Q    2.814      0.021       -0.035    ...                       0      1
# D403A    3.149     -0.007        0.257    ...                       0    NaN
# D403A    3.245      0.003        0.123    ...                       0    NaN
# D55G     1.510     -0.065       -0.058    ...                       0    NaN
# D55G     1.553      0.006        0.043    ...                       0    NaN
# E154D    4.355     -0.031       -0.043    ...                       0      0
# E154D    0.528     -0.002       -0.092    ...                       0      0
# E164A    2.626      0.000        0.115    ...                       0    NaN
# E164A    0.880      0.000        0.146    ...                       0    NaN
# E177A    1.328     -0.045        0.126    ...                       0      0
# E177A    3.759     -0.049       -0.583    ...                       0      0
# E406D    4.873      0.405        0.217    ...                       0      1
# E406D    2.749      0.006       -0.579    ...                       0      1
# E426S   -4.012     -0.290        0.040    ...                       0      0
# E426S   -0.985     -0.001       -0.021    ...                       0      0
# G174R   -1.820      0.003        0.492    ...                       0    NaN
# G174R    1.422     -0.030        0.523    ...                       0    NaN
# G22S    -2.328     -0.068       -0.162    ...                       0    NaN
# G22S     0.587     -0.009        0.454    ...                       0    NaN
# H101R    4.233     -0.054       -0.086    ...                       0      0
# H101R   -1.046      0.017        0.348    ...                       0      0
# H178R   -4.241      0.011        0.365    ...                       0    NaN
# H178R   -3.838     -0.029        0.372    ...                       0    NaN
# H223G   -2.708      0.014       -0.331    ...                       0    NaN
# H223G    2.131     -0.040       -0.064    ...                       0    NaN
# H315N    4.490     -0.047       -0.145    ...                       0    NaN
# H315N    1.240      0.005        0.214    ...                       0    NaN
# H328C    2.423      0.043       -0.190    ...                       0    NaN
# H328C   -0.587      0.021       -0.302    ...                       0    NaN
# ...        ...        ...          ...    ...                     ...    ...
# W120A    1.307      0.035        0.268    ...                       0    NaN
# W120A   -0.889      0.017        0.088    ...                       0    NaN
# W120F    0.085      0.049       -0.838    ...                       0    NaN
# W120F   -0.543      0.027       -0.971    ...                       0    NaN
# W247N    2.180     -0.084       -0.469    ...                       0    NaN
# W247N   -0.301      0.033       -0.414    ...                       0    NaN
# W325L    3.789     -0.037       -0.175    ...                       0    NaN
# W325L    2.425      0.058        0.422    ...                       0    NaN
# W34A     0.261     -0.327       -0.041    ...                       0    NaN
# W34A     0.415      0.008        0.430    ...                       0    NaN
# W399C   -2.501      0.062        0.170    ...                       0    NaN
# W399C    3.553      0.003        0.014    ...                       0    NaN
# W399S    1.653      0.024        0.125    ...                       0    NaN
# W399S   -0.628      0.005        0.011    ...                       0    NaN
# W407C    1.531      0.065       -0.134    ...                       0    NaN
# W407C    1.660     -0.022       -0.131    ...                       0    NaN
# W407G    1.408     -0.080       -0.023    ...                       0    NaN
# W407G    0.999      0.011       -0.202    ...                       0    NaN
# W407R    1.746      0.018       -0.077    ...                       0    NaN
# W407R    0.944     -0.001       -0.085    ...                       0    NaN
# Y166D   -0.023      0.115        0.121    ...                       0    NaN
# Y166D   -5.780      0.052        0.104    ...                       0    NaN
# Y294A    1.061      0.068        0.145    ...                       0      1
# Y294A   -0.722     -0.023        0.075    ...                       0      1
# Y295A    3.960      0.028       -0.121    ...                       0    NaN
# Y295A    4.702      0.010        0.435    ...                       0    NaN
# Y75H     0.777     -0.018       -0.230    ...                       0    NaN
# Y75H    -1.974      0.114       -0.314    ...                       0    NaN
# Y75H     1.559      0.069        0.180    ...                       0    NaN
# Y75H     1.321      0.073        0.116    ...                       0    NaN
#
#            y  protein_on_gel  in_plos_paper  native  designed  position  \
# C167Q  0.264               1              1       C         Q       167
# C167Q  0.264               1              1       C         Q       167
# D403A    NaN             NaN            NaN     NaN       NaN       NaN
# D403A    NaN             NaN            NaN     NaN       NaN       NaN
# D55G     NaN             NaN            NaN     NaN       NaN       NaN
# D55G     NaN             NaN            NaN     NaN       NaN       NaN
# E154D  0.969               1              1       E         D       154
# E154D  0.969               1              1       E         D       154
# E164A    NaN             NaN            NaN     NaN       NaN       NaN
# E164A    NaN             NaN            NaN     NaN       NaN       NaN
# E177A  1.006               1              1       E         A       177
# E177A  1.006               1              1       E         A       177
# E406D  0.555               1              1       E         D       406
# E406D  0.555               1              1       E         D       406
# E426S  1.190               1              1       E         S       426
# E426S  1.190               1              1       E         S       426
# G174R    NaN             NaN            NaN     NaN       NaN       NaN
# G174R    NaN             NaN            NaN     NaN       NaN       NaN
# G22S     NaN             NaN            NaN     NaN       NaN       NaN
# G22S     NaN             NaN            NaN     NaN       NaN       NaN
# H101R  1.500               1              1       H         R       101
# H101R  1.500               1              1       H         R       101
# H178R    NaN             NaN            NaN     NaN       NaN       NaN
# H178R    NaN             NaN            NaN     NaN       NaN       NaN
# H223G    NaN             NaN            NaN     NaN       NaN       NaN
# H223G    NaN             NaN            NaN     NaN       NaN       NaN
# H315N    NaN             NaN            NaN     NaN       NaN       NaN
# H315N    NaN             NaN            NaN     NaN       NaN       NaN
# H328C    NaN             NaN            NaN     NaN       NaN       NaN
# H328C    NaN             NaN            NaN     NaN       NaN       NaN
# ...      ...             ...            ...     ...       ...       ...
# W120A    NaN             NaN            NaN     NaN       NaN       NaN
# W120A    NaN             NaN            NaN     NaN       NaN       NaN
# W120F    NaN             NaN            NaN     NaN       NaN       NaN
# W120F    NaN             NaN            NaN     NaN       NaN       NaN
# W247N    NaN             NaN            NaN     NaN       NaN       NaN
# W247N    NaN             NaN            NaN     NaN       NaN       NaN
# W325L    NaN             NaN            NaN     NaN       NaN       NaN
# W325L    NaN             NaN            NaN     NaN       NaN       NaN
# W34A     NaN             NaN            NaN     NaN       NaN       NaN
# W34A     NaN             NaN            NaN     NaN       NaN       NaN
# W399C    NaN             NaN            NaN     NaN       NaN       NaN
# W399C    NaN             NaN            NaN     NaN       NaN       NaN
# W399S    NaN             NaN            NaN     NaN       NaN       NaN
# W399S    NaN             NaN            NaN     NaN       NaN       NaN
# W407C    NaN             NaN            NaN     NaN       NaN       NaN
# W407C    NaN             NaN            NaN     NaN       NaN       NaN
# W407G    NaN             NaN            NaN     NaN       NaN       NaN
# W407G    NaN             NaN            NaN     NaN       NaN       NaN
# W407R    NaN             NaN            NaN     NaN       NaN       NaN
# W407R    NaN             NaN            NaN     NaN       NaN       NaN
# Y166D    NaN             NaN            NaN     NaN       NaN       NaN
# Y166D    NaN             NaN            NaN     NaN       NaN       NaN
# Y294A  0.677               1              1       Y         A       294
# Y294A  0.677               1              1       Y         A       294
# Y295A    NaN             NaN            NaN     NaN       NaN       NaN
# Y295A    NaN             NaN            NaN     NaN       NaN       NaN
# Y75H     NaN             NaN            NaN     NaN       NaN       NaN
# Y75H     NaN             NaN            NaN     NaN       NaN       NaN
# Y75H     NaN             NaN            NaN     NaN       NaN       NaN
# Y75H     NaN             NaN            NaN     NaN       NaN       NaN
#
#               tm         k
# C167Q  38.471567 -0.529354
# C167Q  38.471567 -0.529354
# D403A        NaN       NaN
# D403A        NaN       NaN
# D55G         NaN       NaN
# D55G         NaN       NaN
# E154D  38.699104 -0.688686
# E154D  38.699104 -0.688686
# E164A        NaN       NaN
# E164A        NaN       NaN
# E177A  37.307655 -0.486928
# E177A  37.307655 -0.486928
# E406D  40.554599 -0.926168
# E406D  40.554599 -0.926168
# E426S  39.459240 -1.449480
# E426S  39.459240 -1.449480
# G174R        NaN       NaN
# G174R        NaN       NaN
# G22S         NaN       NaN
# G22S         NaN       NaN
# H101R  40.021708 -0.910848
# H101R  40.021708 -0.910848
# H178R        NaN       NaN
# H178R        NaN       NaN
# H223G        NaN       NaN
# H223G        NaN       NaN
# H315N        NaN       NaN
# H315N        NaN       NaN
# H328C        NaN       NaN
# H328C        NaN       NaN
# ...          ...       ...
# W120A        NaN       NaN
# W120A        NaN       NaN
# W120F        NaN       NaN
# W120F        NaN       NaN
# W247N        NaN       NaN
# W247N        NaN       NaN
# W325L        NaN       NaN
# W325L        NaN       NaN
# W34A         NaN       NaN
# W34A         NaN       NaN
# W399C        NaN       NaN
# W399C        NaN       NaN
# W399S        NaN       NaN
# W399S        NaN       NaN
# W407C        NaN       NaN
# W407C        NaN       NaN
# W407G        NaN       NaN
# W407G        NaN       NaN
# W407R        NaN       NaN
# W407R        NaN       NaN
# Y166D        NaN       NaN
# Y166D        NaN       NaN
# Y294A  39.999766 -0.755361
# Y294A  39.999766 -0.755361
# Y295A        NaN       NaN
# Y295A        NaN       NaN
# Y75H         NaN       NaN
# Y75H         NaN       NaN
# Y75H         NaN       NaN
# Y75H         NaN       NaN
#
# [106 rows x 33 columns]

# %%
thresh = 1 
joined['delta_tm'] = joined.tm - 39.5

l = []
for name, row in joined.iterrows():
    if abs( row.delta_tm ) < thresh:
        l.append( 0 ) 
    else:
        l.append( 1 ) 
        
joined['big'] = l 

feats = [ 
    u'total', u'fa_atr', u'fa_rep', u'fa_sol',
    u'fa_intra_rep', u'fa_elec', u'pro_close', u'hbond_sr_bb',
    u'hbond_lr_bb', u'hbond_bb_sc', u'hbond_sc', u'dslf_fa13',
    u'coordinate_constraint', u'angle_constraint', u'dihedral_constraint',
    u'rama', u'omega', u'fa_dun', u'p_aa_pp', u'ref', u'chainbreak',
    u'res_type_constraint', u'big', 
]

# feats = [ 'big', 'total', 'fa_dun' ] 

my_df = joined[ feats ].dropna()

X = my_df.drop( [ 'big' ], axis=1 ).as_matrix()
y = my_df.big.as_matrix()

import numpy as np
from scipy import interp
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import StratifiedKFold

###############################################################################
# Data IO and generation

# import some data to play with
my_df = joined[ feats ].dropna()
X = my_df.drop( [ 'big' ], axis=1 ).as_matrix()
y = my_df.big.as_matrix()
n_samples, n_features = X.shape

random_state = np.random.RandomState(0)

###############################################################################
# Classification and ROC analysis

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(y, n_folds=5)
classifier = svm.SVC(kernel='linear', probability=True,random_state=random_state)

mean_tpr = 0.0
mean_fpr = np.linspace(0, 1, 100)
all_tpr = []

for i, (train, test) in enumerate(cv):
    probas_ = classifier.fit(X[train], y[train]).predict_proba(X[test])
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
    mean_tpr += interp(mean_fpr, fpr, tpr)
    mean_tpr[0] = 0.0
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')

mean_tpr /= len(cv)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, 'k--',
    label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure( figsize=( 4, 4 ) )
plt.scatter( joined.delta_tm, joined.total, color='k' )
#plt.plot( ( joined.tm.min(), joined.tm.max() ), ( joined.total.max() , joined.total.min() ), color='red', alpha=0.4 ) #perfect correlation
plt.xlabel( 'Experimental $\Delta T_m$' )
plt.ylabel( 'Predicted $\Delta \Delta G$' )

from scipy.stats import pearsonr, kendalltau, spearmanr
print kendalltau( joined.delta_tm.values, joined.total.values )
print spearmanr( joined.delta_tm.values, joined.total.values )
# Out:
# KendalltauResult(correlation=0.78723041955139983, pvalue=5.7664171774290183e-33)
# SpearmanrResult(correlation=0.11427347845932057, pvalue=0.24345561294820742)

# %%
for col, dtype in zip( joined.columns, joined.dtypes ):
    if str( dtype ) == 'float64' and str( col ) not in ['tm', 'k']:
        print col, dtype
        plt.figure( figsize=( 3, 3 ) )
        plt.scatter( joined.tm, joined[col], color='k' )
        #plt.plot( ( joined.tm.min(), joined.tm.max() ), ( joined.total.max() , joined.total.min() ), color='red', alpha=0.4 ) #perfect correlation
        plt.xlabel( 'Experimental Tm' )
        plt.ylabel( col )
        plt.show()
# Out:
# total float64
# fa_atr float64
# fa_rep float64
# fa_sol float64
# fa_intra_rep float64
# fa_elec float64
# pro_close float64
# hbond_sr_bb float64
# hbond_lr_bb float64
# hbond_bb_sc float64
# hbond_sc float64
# dslf_fa13 float64
# coordinate_constraint float64
# angle_constraint float64
# dihedral_constraint float64
# rama float64
# omega float64
# fa_dun float64
# p_aa_pp float64
# ref float64
# chainbreak float64
# res_type_constraint float64
# beads float64
# y float64
# protein_on_gel float64
# in_plos_paper float64
# position float64
# delta_tm float64

# %% [markdown]
# So nothing really correlates, even predicted $\Delta G$ of folding. Bummmer.

# %%
new_df = joined[ [ 'total', 'delta_tm' ] ]
new_df = new_df.dropna()

# %%
plt.scatter( new_df.total, new_df.delta_tm )

# %%
preds = []
actuals = [] 


from numpy import linspace

xx = []
yy = []

for i in linspace( 0, 1, 100 ):
    
    binsize = 1
    temp_bin_size = i

    for name, row in joined.iterrows():

        # classifier, how did we do? 
        # -1 is less stable, 0 is like WT, 1 is more stable 

        # preds 
        if -binsize <= row.total <= binsize:
            pred = 0 
        elif row.total < -binsize:
            pred = -1 
        elif row.total > binsize:
            pred = 1 

        # actuals 
        # preds 
        if -temp_bin_size <= row.delta_tm <= temp_bin_size:
            actual = 0 
        elif row.delta_tm < -temp_bin_size:
            actual = -1 
        elif row.delta_tm > temp_bin_size:
            actual = 1 

        preds.append( pred )
        actuals.append( actual )

    correct = [] 

    for ( pred, actual ) in zip( preds, actuals ):
        if pred == actual:
            correct.append( 1 )
        else:
            correct.append( 0 )

    xx.append( i )
    yy.append( sum( correct ) )
    
plt.scatter( xx, yy )

# %% [markdown]
# # Rosetta plus machine learning [outperforms `ddg_monomer`?]

# %% [markdown]
# Instead, let's make models of the mutants using `EnzRepackMinimize` and then try to use machine learning to get better correlation.

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import BaggingRegressor
from sklearn.grid_search import GridSearchCV
from glob import glob 

dfs = [ pandas.read_csv( i, sep=r'\s+' ) for i in glob( 'enzdes/out/*sc' ) ]
df = pandas.concat( dfs )
print len( df ), 'models'
df.sample( 10 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-34f49a0a0878> in <module>()
#       5
#       6 dfs = [ pandas.read_csv( i, sep=r'\s+' ) for i in glob( 'enzdes/out/*sc' ) ]
# ----> 7 df = pandas.concat( dfs )
#       8 print len( df ), 'models'
#       9 df.sample( 10 )
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     810                        keys=keys, levels=levels, names=names,
#     811                        verify_integrity=verify_integrity,
# --> 812                        copy=copy)
#     813     return op.get_result()
#     814
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     843
#     844         if len(objs) == 0:
# --> 845             raise ValueError('No objects to concatenate')
#     846
#     847         if keys is None:
#
# ValueError: No objects to concatenate

# %%
from Bio.SeqUtils import IUPACData
import screed

for record in screed.open( 'data/bglb.pep' ):
    seq = record.sequence

# blarg, we have to reindex the DataFrame because of how I named the Rosetta output
l = []
for i in df.description:
    j = i.split( '_' )[1]
    pos = j[:-3]
    native = seq[ int(pos) - 1 ].upper()
    designed = IUPACData.protein_letters_3to1[ j[-3:].capitalize() ] # good god why
    l.append( '{}{}{}'.format( native, pos, designed ) )
df['name'] = l

# %%
df.head( 20 )

# %%
# get lowest 10% energy by total_score 
def low_10( df ):
    return df.sort( 'total_score' ).head( 10 )

df = df.groupby( 'name' ).apply( low_10 )
df.head( 20 )

# %%
# reindex and join with experimental data 
df.index = df.name 
joined = df.join( fits )
joined.sample( 10 )

# %%
# diagnostics and droping NaN values 
print len( joined )
joined.dropna( inplace = True )
print len( joined ), 'models'

# clean up data for sklearn
x_cols = [ u'total_score', u'fa_rep', u'hbond_sc', u'tot_pstat_pm',
       u'tot_nlpstat_pm', u'tot_burunsat_pm', u'tot_hbond_pm',
       u'tot_NLconts_pm', u'tot_nlsurfaceE_pm', u'tot_total_charge',
       u'tot_total_pos_charges', u'tot_total_neg_charges', u'tot_seq_recovery',
       u'SR_1_total_score', u'SR_1_fa_rep', u'SR_1_hbond_sc',
       u'SR_1_hbond_pm', u'SR_1_burunsat_pm',
       u'SR_1_pstat_pm', u'SR_1_nlpstat_pm', u'SR_2_total_score',
       u'SR_2_fa_rep', u'SR_2_hbond_sc', u'SR_2_all_cst', u'SR_2_hbond_pm',
       u'SR_2_burunsat_pm', u'SR_2_pstat_pm', u'SR_2_nlpstat_pm',
       u'SR_3_total_score', u'SR_3_fa_rep', u'SR_3_hbond_sc', 
       u'SR_3_hbond_pm', u'SR_3_burunsat_pm', u'SR_3_pstat_pm',
       u'SR_3_nlpstat_pm', u'SR_4_total_score', u'SR_4_fa_rep',
       u'SR_4_hbond_sc', u'SR_4_hbond_pm',
       u'SR_4_burunsat_pm', u'SR_4_pstat_pm', u'SR_4_nlpstat_pm',
       u'SR_5_total_score', u'SR_5_fa_rep', u'SR_5_hbond_sc', u'SR_5_all_cst',
       u'SR_5_interf_E_1_2', u'SR_5_dsasa_1_2', u'SR_5_hbond_pm',
       u'SR_5_burunsat_pm', ]

X = joined[ x_cols ]
y = joined[ 'tm' ]

# %% [markdown]
# Now we actually fit the data to the model

# %%
params = { 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1] }

from sklearn.cross_validation import StratifiedKFold
from scipy.stats.stats import pearsonr

for i in [ 1, 10, 100, 1000 ]:
    #skf = StratifiedKFold( y, 10 )
    net = ElasticNetCV( cv=10 )
    grid = GridSearchCV( net, params )
    bag = BaggingRegressor( grid, n_estimators=i )
    bag.fit( X, y )

    preds = bag.predict( X )
    print 'Number of models', i 
    print 'PCC={}'.format( pearsonr( preds, y ) )

    plt.figure( figsize=(4,4) )
    plt.scatter( preds, y, alpha=0.3, marker='.', color='k' )
    plt.xlabel( 'Predicted' )
    plt.ylabel( 'Actual' )
    plt.show()
    
    weights = pandas.DataFrame( zip( X.columns, bag.estimators_[0].best_estimator_.coef_ ), columns=['feature', 'weight'] )
    print weights.sort( 'weight' )[0:11]

# %% [markdown]
# So that's fairly underwhelming. Let's try something else.
#
# ## Structures minimized with `ddg_monomer` scored using EnzDes-style metrics

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import BaggingRegressor
from sklearn.grid_search import GridSearchCV
from glob import glob 


df = pandas.read_csv( 'enzdes_score_ddg/out/score.sc', sep='\s+' )
print len( df ), 'models'
df.sample( 10 )

# # reindex and join with experimental data 
# df.index = df.name 
# joined = df.join( fits )
# joined.sample( 10 )

# # diagnostics and droping NaN values 
# print len( joined )
# joined.dropna( inplace = True )
# print len( joined ), 'models'

# # clean up data for sklearn
# x_cols = [ u'total_score', u'fa_rep', u'hbond_sc', u'tot_pstat_pm',
#        u'tot_nlpstat_pm', u'tot_burunsat_pm', u'tot_hbond_pm',
#        u'tot_NLconts_pm', u'tot_nlsurfaceE_pm', u'tot_total_charge',
#        u'tot_total_pos_charges', u'tot_total_neg_charges', u'tot_seq_recovery',
#        u'SR_1_total_score', u'SR_1_fa_rep', u'SR_1_hbond_sc',
#        u'SR_1_hbond_pm', u'SR_1_burunsat_pm',
#        u'SR_1_pstat_pm', u'SR_1_nlpstat_pm', u'SR_2_total_score',
#        u'SR_2_fa_rep', u'SR_2_hbond_sc', u'SR_2_all_cst', u'SR_2_hbond_pm',
#        u'SR_2_burunsat_pm', u'SR_2_pstat_pm', u'SR_2_nlpstat_pm',
#        u'SR_3_total_score', u'SR_3_fa_rep', u'SR_3_hbond_sc', 
#        u'SR_3_hbond_pm', u'SR_3_burunsat_pm', u'SR_3_pstat_pm',
#        u'SR_3_nlpstat_pm', u'SR_4_total_score', u'SR_4_fa_rep',
#        u'SR_4_hbond_sc', u'SR_4_hbond_pm',
#        u'SR_4_burunsat_pm', u'SR_4_pstat_pm', u'SR_4_nlpstat_pm',
#        u'SR_5_total_score', u'SR_5_fa_rep', u'SR_5_hbond_sc', u'SR_5_all_cst',
#        u'SR_5_interf_E_1_2', u'SR_5_dsasa_1_2', u'SR_5_hbond_pm',
#        u'SR_5_burunsat_pm', ]

# X = joined[ x_cols ]
# y = joined[ 'tm' ]

# params = { 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1] }

# from sklearn.cross_validation import StratifiedKFold
# from scipy.stats.stats import pearsonr

# for i in [ 1, 10, 100, 1000 ]:
#     #skf = StratifiedKFold( y, 10 )
#     net = ElasticNetCV( cv=10 )
#     grid = GridSearchCV( net, params )
#     bag = BaggingRegressor( grid, n_estimators=i )
#     bag.fit( X, y )

#     preds = bag.predict( X )
#     print 'Number of models', i 
#     print 'PCC={}'.format( pearsonr( preds, y ) )

#     plt.figure( figsize=(4,4) )
#     plt.scatter( preds, y, alpha=0.3, marker='.', color='k' )
#     plt.xlabel( 'Predicted' )
#     plt.ylabel( 'Actual' )
#     plt.show()
    
#     weights = pandas.DataFrame( zip( X.columns, bag.estimators_[0].best_estimator_.coef_ ), columns=['feature', 'weight'] )
#     print weights.sort( 'weight' )[0:11]

# %% [markdown]
# ## Individual plots for W120F and N407C
#
# As per Siena's request Sunday, March 20

# %%
import pandas 

df = pandas.read_csv( '/Users/alex/Downloads/Bagel Thermostability - Best Mutants.csv' )
grouped = df.groupby( [ 'mutant', 'trial' ] )

for i, df in grouped:
    df.rate = df.rate / df.rate.max()

    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]

    p0 = ( df.temp.mean(), slope )
    popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
    perr = sqrt( diag( pcov ) ) 

    plt.figure()
    plt.xlabel( 'T (C)' )
    plt.xlim( 25, 55 )
    plt.scatter( df.temp, df.rate )
    xs = linspace( df.temp.min(), df.temp.max(), 100 )
    plt.plot( xs, f( xs, *popt ) )
    wts = linspace( 30, 50, 100 )
    plt.plot( wts, f( wts, 39.88, -1.12 ) ) 
    plt.legend( [ i, 'Wild type BglB'] )
    plt.text( 30, 0.2, 'Tm = {:2.1f} C'.format( popt[0] ), size=12 )
    plt.text( 30, 0, 'k = {:2.2f}'.format( popt[1] ), size=12 )
    plt.show()

# %%
import pandas 

df = pandas.read_csv( '/Users/alex/Downloads/Bagel Thermostability - Best Mutants.csv' )
grouped = df.groupby( [ 'mutant' ] )

for i, df in grouped:
    df.rate = df.rate / df.rate.max()

    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]

    p0 = ( df.temp.mean(), slope )
    popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
    perr = sqrt( diag( pcov ) ) 

    plt.figure()
    plt.xlabel( 'T (C)' )
    plt.xlim( 25, 55 )
    plt.scatter( df.temp, df.rate, c=df.trial, cmap='Blues' )
    xs = linspace( df.temp.min(), df.temp.max(), 100 )
    plt.plot( xs, f( xs, *popt ) )
    wts = linspace( 30, 50, 100 )
    plt.plot( wts, f( wts, 39.88, -1.12 ) ) 
    plt.legend( [ i, 'Wild type BglB'] )
    plt.text( 30, 0.2, 'Tm = {:2.1f} C'.format( popt[0] ), size=12 )
    plt.text( 30, 0, 'k = {:2.2f}'.format( popt[1] ), size=12 )
    plt.show()

# %% [markdown]
# ## Production and purification data

# %%
df = pandas.read_csv( 'data/Bagel Thermostability - Thermostability protein production progress.csv', index_col='mutant' )
