# %% [markdown]
# # Thermal stability of hundreds of point mutants of a family 1 glycoside hydrolase

# %% [markdown]
# Here, we are determining the thermal stability of about a hundred and fifty point mutants of BglB (model based on 2JIE). After automated mutagensis of the BglB coding sequence, protein production, and protein purification, each mutant's activity at 100 mM pNPG at pH 7.4 at a range of temperatures from 30 C to 50 C was measured using the rate of formation of the pNPG hydrolysis product p-nitrophenol.
#
# Data were collected into a table with the columns `well`, `rate`, and `mutant` using Google Docs and exported to CSV, which is the input file here.
#
# ## Data input and cleanup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
from scipy.optimize import curve_fit 
from numpy import log, exp, linspace, sqrt, diag
from sklearn.linear_model import LinearRegression
import os
import re 

df = pandas.read_csv( 'data/data_2016_03_09.csv' )
raw = len( df )
df.index = df.mutant
df.drop( 'mutant', inplace=True )
df.drop( ['WT', 'WT1'], inplace=True )
df.dropna( inplace=True ) 

with open( 'data/allowed_mutants.txt' ) as fn:
    mutants = [ i.split('.')[0].upper() for i in fn.readlines() if len( i ) > 1 ]
    
def is_good( name ):
    return name in mutants 

# this is a sanity-checking routine for "off-by-threes"
# let's just rename all the tubes
not_allowed = []
l = []
for name in df.index:
    #print name
    if is_good( name ):
        l.append( name )
    else:
        new = name[0] + str( int( re.findall( r'\d+', name )[0] ) - 3 ) + name[-1]
        if is_good( new ):
            l.append( new )
        else:
            l.append( 'drop_me' )
            not_allowed.append( name )
            
assert len( df.index ) == len( l ) # do not want to reindex wrongly! 
df.index = l
df.mutant = df.index 
df.drop( ['drop_me'], inplace=True )

# temperature keys as CSV files in data/
temp_key = pandas.read_csv( 'data/temp_key.csv' )
temp_key.index = temp_key.Well
df['temp'] = df.well.str[0].map( temp_key.Celsius.to_dict() ) 
df.dropna( inplace=True )
pos_and_neg = len( df )
df = df[( df.rate > 0 )]
df.sample( 10 )

# diagnostics 
print 'Input has {} rates. {} will be used, {} will be dropped because of mutant name, {} because negative).'.format( raw, len( df ), raw - pos_and_neg , pos_and_neg - len( df ) ), 
print 'Samples {} were dropped because the given native residue does not match the BglB sequence and is not off by three'.format( set( not_allowed ) )
# Out:
# Input has 3048 rates. 2350 will be used, 48 will be dropped because of mutant name, 650 because negative). Samples set(['Q384R']) were dropped because the given native residue does not match the BglB sequence and is not off by three

# %% [markdown]
# ## Determine protein parameters Tm and k
#
# To determine protein parameters Tm and k (steepness of melting curve), we will fit the cleaned data to the logistic equation. To determine starting parameters for the search algorithm `curve_fit`, we'll just fit a straight line to the data using SciKit-Learn's linear regression.

# %%
# logistic equation 
def f(x, x0, k): 
    return 1/(1+exp(-k*(x-x0)))

# util function to fit a mutant 
def fit( df ):
    name = df.mutant.unique()[0]
    df.rate = df.rate / df.rate.max()
    
    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]
    
    # try fitting to logistic eqn using approximate params from linear fit
    try:
        p0 = ( df.temp.mean(), slope )
        popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
        perr = sqrt( diag( pcov ) ) 
        if 30 < popt[0] < 50 and popt[1] < 0: # biological assay limits, and make sure k is the right sign
            return pandas.Series( popt, index=['tm', 'k'] )
        else:
            #iffy += [ name ]
            raise Exception( 'Warning: dropping fit for {0} because Tm of {1:2.2f} is outside range 30-50 C'.format( name, popt[0] ) )
    except Exception as e:
        print e
    
grouped = df.groupby( by='mutant' )
fits = grouped.apply( fit )
print ''
print 'Successfully fit {} of {} samples to the logistic equation'.format( len( fits.dropna() ), len( grouped ) )
# Out:
# Warning: dropping fit for D403A because Tm of 17.05 is outside range 30-50 C
# Warning: dropping fit for E164A because Tm of 47.48 is outside range 30-50 C
# Warning: dropping fit for E164G because Tm of 20.99 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# Warning: dropping fit for F415A because Tm of -9.15 is outside range 30-50 C
# Warning: dropping fit for F415N because Tm of 35.98 is outside range 30-50 C
# Warning: dropping fit for G355A because Tm of 50.07 is outside range 30-50 C
# Warning: dropping fit for H119E because Tm of 98.16 is outside range 30-50 C
# Warning: dropping fit for H119N because Tm of 11.41 is outside range 30-50 C
# Warning: dropping fit for H178R because Tm of 40.61 is outside range 30-50 C
# Warning: dropping fit for H315N because Tm of 55.55 is outside range 30-50 C
# Warning: dropping fit for H379R because Tm of 32.13 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# Warning: dropping fit for M221A because Tm of 47.90 is outside range 30-50 C
# Warning: dropping fit for M323K because Tm of 54.77 is outside range 30-50 C
# Warning: dropping fit for N293A because Tm of 178.39 is outside range 30-50 C
# Warning: dropping fit for N293D because Tm of 54.12 is outside range 30-50 C
# Warning: dropping fit for N293Q because Tm of 23.07 is outside range 30-50 C
# Warning: dropping fit for Q19A because Tm of 201.35 is outside range 30-50 C
# Warning: dropping fit for Q19C because Tm of 15.36 is outside range 30-50 C
# Warning: dropping fit for R240D because Tm of 33.30 is outside range 30-50 C
# Warning: dropping fit for R240E because Tm of 53.20 is outside range 30-50 C
# Warning: dropping fit for S16N because Tm of 35.19 is outside range 30-50 C
# Warning: dropping fit for T296A because Tm of 88.07 is outside range 30-50 C
# Warning: dropping fit for W120A because Tm of 80.35 is outside range 30-50 C
# Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# Warning: dropping fit for W34A because Tm of 26.12 is outside range 30-50 C
# Warning: dropping fit for W399A because Tm of 39.78 is outside range 30-50 C
# Warning: dropping fit for W399C because Tm of 37.42 is outside range 30-50 C
# Warning: dropping fit for W399G because Tm of 29.82 is outside range 30-50 C
# Warning: dropping fit for W399R because Tm of 51.98 is outside range 30-50 C
# Warning: dropping fit for W399S because Tm of 63.22 is outside range 30-50 C
# Warning: dropping fit for W407A because Tm of 54.67 is outside range 30-50 C
# Warning: dropping fit for W407Q because Tm of 35.20 is outside range 30-50 C
# Warning: dropping fit for W407R because Tm of 40.54 is outside range 30-50 C
# Warning: dropping fit for Y166P because Tm of 32.13 is outside range 30-50 C
# Warning: dropping fit for Y295A because Tm of 34.69 is outside range 30-50 C
# Warning: dropping fit for Y295G because Tm of 19.58 is outside range 30-50 C
#
# Successfully fit 79 of 117 samples to the logistic equation

# %%
fits
# Out:
#                tm         k
# mutant
# A192S   39.082601 -0.906304
# A356A   39.888266 -1.124698
# A357A   39.094581 -0.325209
# A408A   39.955931 -1.260729
# C167A   39.735604 -1.388447
# C167Q   38.471567 -0.529354
# D403A         NaN       NaN
# E154D   38.699104 -0.688686
# E164A         NaN       NaN
# E164G         NaN       NaN
# E164R         NaN       NaN
# E177A   37.307655 -0.486928
# E177K   36.649702 -0.666761
# E177L   39.223503 -0.520210
# E222A   36.743814 -0.656627
# E222H   34.708312 -0.636223
# E222K   38.526868 -0.464967
# E222Q   39.421645 -0.815422
# E222R   39.086509 -0.748890
# E222Y   37.041199 -0.593383
# E353A   43.259171 -0.093197
# E406A   39.934310 -1.524719
# E406D   40.554599 -0.926168
# E426S   39.459240 -1.449480
# F415A         NaN       NaN
# F415N         NaN       NaN
# F72H    38.606014 -0.415987
# G355A         NaN       NaN
# H101R   40.021708 -0.910848
# H119A   40.158045 -1.028931
# ...           ...       ...
# T218A   40.045653 -1.122531
# T296A         NaN       NaN
# T352A   38.027066 -0.745704
# V52G    39.206299 -1.005693
# W120A         NaN       NaN
# W120F   41.510527 -0.462998
# W120H   39.888395 -0.574204
# W325A   40.188242 -0.362363
# W325C   39.181842 -0.888861
# W325G         NaN       NaN
# W325H   37.032928 -0.009632
# W325L   30.523417 -0.135566
# W325R   39.873792 -0.713240
# W34A          NaN       NaN
# W399A         NaN       NaN
# W399C         NaN       NaN
# W399G         NaN       NaN
# W399R         NaN       NaN
# W399S         NaN       NaN
# W407A         NaN       NaN
# W407G   31.738916 -0.140748
# W407Q         NaN       NaN
# W407R         NaN       NaN
# W409Y   36.614921 -0.392453
# Y166P         NaN       NaN
# Y18A    37.172903 -0.346462
# Y294A   39.999766 -0.755361
# Y294F   33.776906 -0.175158
# Y295A         NaN       NaN
# Y295G         NaN       NaN
#
# [117 rows x 2 columns]

# %%
tms = fits[(fits.tm > 0)].tm - 39.5 
from numpy import array 

a = array( [tms, tms] ).T
plt.figure( figsize=( 1, 20 ) ) 
plt.yticks( [ 0.5 + i for i in range( len( fits.index ) ) ], fits.index )
plt.xticks( [ 1 ], [ 'tm' ] ) 
plt.pcolormesh( a, cmap='Blues' )

# %% [markdown]
# ## Diagnostic plots to help determine goodness of fits

# %%
#!mkdir plots 
for index, df in grouped:
    name = df.mutant.unique()[0]
    rate = df.rate / df.rate.max() 
    plt.figure( figsize=(2,2) )
    plt.scatter( df.temp, rate, alpha=0.7, color='black', marker='.' )
    popt = fits.loc[ name ]
    if popt is not None:
        x_space = linspace( df.temp.min(), df.temp.max(), 100 )
        plt.plot( x_space, f( x_space, *popt ), alpha=0.5, color='purple' )
    plt.xlabel( 'T (C)' )
    plt.ylabel( 'Normalized rate')
    plt.xticks( [ 30, 40, 50 ] )
    plt.yticks( [ 0, 0.5, 1 ] )
    plt.title( name )
    plt.tight_layout()
    plt.savefig( 'plots/%s.pdf' % name, format='pdf' )
    plt.show()
    plt.close()

# %%
# add metadata
fits['native'] = fits.index.str[0]
fits['designed'] = fits.index.str[-1]
fits['position'] = fits.index.str[1:-1].astype( int )
fits.sample( 10 )
# Out:
#                tm         k native designed  position
# mutant
# T15A    38.696923 -0.457046      T        A        15
# T296A         NaN       NaN      T        A       296
# N220A   38.631057 -0.656223      N        A       220
# M221A         NaN       NaN      M        A       221
# M323K         NaN       NaN      M        K       323
# N354A   40.557793 -0.335794      N        A       354
# Q19S    36.470973 -0.502002      Q        S        19
# W325R   39.873792 -0.713240      W        R       325
# Y294F   33.776906 -0.175158      Y        F       294
# N163C   37.698608 -0.338415      N        C       163

# %%
# makes resfiles for DDG Rosetta app 
#!mkdir ddg/resfiles 

for ( index, series ) in fits.iterrows():
    with open( 'ddg/resfiles/{}'.format( index ), 'w' ) as fn:
        fn.write( 'NATRO\nSTART\n{} A PIKAA {}'.format( series.position, series.designed ) )

# %%
# %%bash
# # this will run the Rosetta app `ddg_monomer` on all the mutants in `fits`, above
#
# #ls ddg/resfiles > ddg/list
# #NUM=$( wc -l ddg/list | cut -d' ' -f1 )
# #cd ddg && sbatch --array=1-${NUM} sub.sh

# %% [markdown]
# ## Comparison between Rosetta `ddg_monomer` app and experimental results

# %%
! ( head -1 ddg/ddg_predictions.out && grep -v desc ddg/ddg_predictions.out ) > ddg/readable_output

# %%
preds = pandas.read_csv( 'ddg/readable_output', sep='\s+' )
preds.index = preds.description.values
joined = preds.join( fits )
joined
# Out:
#        ddG: description   total  fa_atr  fa_rep  fa_sol  fa_intra_rep  \
# C167Q  ddG:       C167Q   7.123   4.771   0.167  -7.495         0.008
# C167Q  ddG:       C167Q   3.917  -9.104   3.124   5.132         0.000
# D403A  ddG:       D403A  -0.084   8.162  -2.992 -11.071        -0.024
# D403A  ddG:       D403A  -0.037   5.611  -0.695 -10.098        -0.010
# D55G   ddG:        D55G  -5.800   2.399   0.108  -5.663        -0.008
# D55G   ddG:        D55G  -2.896   2.002   0.558  -5.176        -0.022
# E154D  ddG:       E154D   5.108  -4.377   0.348   1.037        -0.007
# E154D  ddG:       E154D   1.733   2.605   0.279  -1.832         0.018
# E164A  ddG:       E164A   1.246  11.627  -1.906 -13.616        -0.085
# E164A  ddG:       E164A  -3.223   7.296  -1.810 -10.824         0.003
# E177A  ddG:       E177A  -0.731   1.029  -0.495  -3.457        -0.024
# E177A  ddG:       E177A  -0.361   7.804  -1.012 -10.885         0.003
# E406D  ddG:       E406D  10.201  -0.375  -0.568   0.573         0.011
# E406D  ddG:       E406D   1.322   6.610  -0.407  -7.735         0.006
# E426S  ddG:       E426S  -3.236  -1.003  -0.263   4.655        -0.008
# E426S  ddG:       E426S  -0.222  -0.024   1.390  -0.187        -0.009
# G174R  ddG:       G174R  13.066 -10.880   4.472  15.257         0.061
# G174R  ddG:       G174R  18.259  -7.393   5.560  10.213         0.047
# G22S   ddG:        G22S   2.216  -2.363   5.302   1.628         0.010
# G22S   ddG:        G22S   8.951  -3.006   5.576   2.627        -0.016
# H101R  ddG:       H101R   3.084   3.550  -0.581  -4.436        -0.003
# H101R  ddG:       H101R   0.543   3.462  -0.754  -0.705         0.010
# H178R  ddG:       H178R   0.562  -0.355   0.413   7.517         0.108
# H178R  ddG:       H178R   2.399  -3.592  -0.635  10.348         0.132
# H223G  ddG:       H223G   0.613   9.372  -2.140  -2.830         0.017
# H223G  ddG:       H223G   5.618  14.442  -1.874 -11.092         0.021
# H315N  ddG:       H315N   5.300   3.977  -0.244  -4.216         0.017
# H315N  ddG:       H315N   0.095   1.303  -0.243  -0.376         0.016
# H328C  ddG:       H328C  -2.408  10.578  -0.731 -10.742        -0.019
# H328C  ddG:       H328C  -0.766   3.783   0.948  -2.596         0.012
# ...     ...         ...     ...     ...     ...     ...           ...
# W120A  ddG:       W120A   7.079  19.364  -4.741  -7.961        -0.037
# W120A  ddG:       W120A   4.122  20.385  -5.606  -8.105        -0.036
# W120F  ddG:       W120F   1.691   6.595  -3.799  -4.736        -0.006
# W120F  ddG:       W120F  -1.773   5.915  -3.021  -4.014        -0.008
# W247N  ddG:       W247N   7.820  11.106  -3.131   0.168        -0.026
# W247N  ddG:       W247N   8.209  14.747  -0.432  -4.167        -0.024
# W325L  ddG:       W325L   5.585  16.415  -2.039 -11.910         0.164
# W325L  ddG:       W325L   5.549  17.186  -1.460 -12.269         0.150
# W34A   ddG:        W34A   8.512  21.478  -3.590  -6.014        -0.017
# W34A   ddG:        W34A   9.688  16.985  -0.915  -4.455        -0.040
# W399C  ddG:       W399C   4.282  16.451  -1.498  -5.500        -0.028
# W399C  ddG:       W399C   7.645  15.670   0.048  -9.383        -0.050
# W399S  ddG:       W399S   9.946  12.606   0.185  -4.508        -0.048
# W399S  ddG:       W399S   5.103  19.739  -1.347 -10.282        -0.025
# W407C  ddG:       W407C  11.852  17.714  -3.185  -6.711         0.034
# W407C  ddG:       W407C   7.936  18.149  -2.554  -7.410        -0.038
# W407G  ddG:       W407G   5.351  20.957  -3.000 -10.517        -0.024
# W407G  ddG:       W407G   7.485  16.196  -2.838  -4.310        -0.037
# W407R  ddG:       W407R  12.019   5.413  -0.969   5.741        -0.028
# W407R  ddG:       W407R   7.325  10.600  -2.459   0.372        -0.031
# Y166D  ddG:       Y166D   8.362   4.285   0.637   4.117        -0.046
# Y166D  ddG:       Y166D   4.113   0.855  -2.694  12.115         0.003
# Y294A  ddG:       Y294A   8.613  15.448  -1.033  -5.825        -0.055
# Y294A  ddG:       Y294A   6.037  14.635  -0.395  -5.779        -0.032
# Y295A  ddG:       Y295A  13.060  12.999  -1.798  -9.511         0.010
# Y295A  ddG:       Y295A  10.874  18.604  -3.099 -14.807        -0.003
# Y75H   ddG:        Y75H   3.305   1.674  -2.389   1.336        -0.023
# Y75H   ddG:        Y75H   5.061   3.859  -0.733   1.711        -0.011
# Y75H   ddG:        Y75H   6.024   5.259  -1.593  -0.733        -0.010
# Y75H   ddG:        Y75H   4.991   1.300  -0.293   1.974        -0.025
#
#        fa_elec  pro_close  hbond_sr_bb    ...     fa_dun  p_aa_pp    ref  \
# C167Q    4.185      0.097       -0.174    ...      3.763   -0.422 -1.533
# C167Q    2.814      0.021       -0.035    ...      2.117    0.163 -1.533
# D403A    3.149     -0.007        0.257    ...     -1.250    0.061  1.880
# D403A    3.245      0.003        0.123    ...     -1.750   -0.155  1.880
# D55G     1.510     -0.065       -0.058    ...     -4.292    0.059  1.427
# D55G     1.553      0.006        0.043    ...     -3.615   -0.141  1.427
# E154D    4.355     -0.031       -0.043    ...     -2.237   -0.096  0.267
# E154D    0.528     -0.002       -0.092    ...     -0.305   -0.009  0.267
# E164A    2.626      0.000        0.115    ...     -5.346    0.136  2.147
# E164A    0.880      0.000        0.146    ...     -2.300   -0.007  2.147
# E177A    1.328     -0.045        0.126    ...     -2.485    0.018  2.147
# E177A    3.759     -0.049       -0.583    ...     -6.020   -0.379  2.147
# E406D    4.873      0.405        0.217    ...     -1.531   -0.245  0.267
# E406D    2.749      0.006       -0.579    ...     -0.941   -0.604  0.267
# E426S   -4.012     -0.290        0.040    ...     -1.595   -0.344  1.730
# E426S   -0.985     -0.001       -0.021    ...     -2.435   -0.274  1.730
# G174R   -1.820      0.003        0.492    ...      8.192    0.152 -0.290
# G174R    1.422     -0.030        0.523    ...      6.088   -0.209 -0.290
# G22S    -2.328     -0.068       -0.162    ...     -0.739    1.173  0.036
# G22S     0.587     -0.009        0.454    ...     -0.196    1.275  0.036
# H101R    4.233     -0.054       -0.086    ...     -0.144    0.005 -0.507
# H101R   -1.046      0.017        0.348    ...      1.305   -0.112 -0.507
# H178R   -4.241      0.011        0.365    ...     -0.159    0.362 -0.507
# H178R   -3.838     -0.029        0.372    ...      1.928   -0.207 -0.507
# H223G   -2.708      0.014       -0.331    ...     -0.246    0.369 -0.217
# H223G    2.131     -0.040       -0.064    ...     -0.767   -0.220 -0.217
# H315N    4.490     -0.047       -0.145    ...     -1.186   -0.234 -1.299
# H315N    1.240      0.005        0.214    ...      1.233    0.262 -1.299
# H328C    2.423      0.043       -0.190    ...     -4.716    0.176 -0.003
# H328C   -0.587      0.021       -0.302    ...     -2.796    0.208 -0.003
# ...        ...        ...          ...    ...        ...      ...    ...
# W120A    1.307      0.035        0.268    ...     -1.543    0.263 -0.336
# W120A   -0.889      0.017        0.088    ...     -0.207   -0.166 -0.336
# W120F    0.085      0.049       -0.838    ...      1.423   -0.603 -0.499
# W120F   -0.543      0.027       -0.971    ...      1.005   -0.457 -0.499
# W247N    2.180     -0.084       -0.469    ...     -2.478    0.446 -1.871
# W247N   -0.301      0.033       -0.414    ...     -1.808    0.046 -1.871
# W325L    3.789     -0.037       -0.175    ...     -2.328    0.131 -0.327
# W325L    2.425      0.058        0.422    ...     -2.146    0.104 -0.327
# W34A     0.261     -0.327       -0.041    ...     -2.405   -0.293 -0.336
# W34A     0.415      0.008        0.430    ...     -2.144    0.286 -0.336
# W399C   -2.501      0.062        0.170    ...     -0.458   -0.095 -0.574
# W399C    3.553      0.003        0.014    ...     -3.192    0.464 -0.574
# W399S    1.653      0.024        0.125    ...     -2.084    0.432 -0.753
# W399S   -0.628      0.005        0.011    ...     -1.237   -0.162 -0.753
# W407C    1.531      0.065       -0.134    ...     -0.131   -0.913 -0.574
# W407C    1.660     -0.022       -0.131    ...     -3.255   -0.984 -0.574
# W407G    1.408     -0.080       -0.023    ...     -1.183   -1.217 -0.789
# W407G    0.999      0.011       -0.202    ...     -0.885   -1.188 -0.789
# W407R    1.746      0.018       -0.077    ...     -1.148   -1.007 -1.078
# W407R    0.944     -0.001       -0.085    ...     -0.763   -1.078 -1.078
# Y166D   -0.023      0.115        0.121    ...      1.495    0.032 -1.419
# Y166D   -5.780      0.052        0.104    ...      5.266    0.585 -1.419
# Y294A    1.061      0.068        0.145    ...     -5.855   -0.054  0.461
# Y294A   -0.722     -0.023        0.075    ...     -2.520    0.156  0.461
# Y295A    3.960      0.028       -0.121    ...     -0.834    0.704  0.461
# Y295A    4.702      0.010        0.435    ...     -0.397    0.694  0.461
# Y75H     0.777     -0.018       -0.230    ...     -0.301   -0.211  0.226
# Y75H    -1.974      0.114       -0.314    ...      1.217   -0.522  0.226
# Y75H     1.559      0.069        0.180    ...      0.442    0.343  0.226
# Y75H     1.321      0.073        0.116    ...     -0.527    0.588  0.226
#
#        chainbreak  res_type_constraint         tm         k  native  designed  \
# C167Q           0                    0  38.471567 -0.529354       C         Q
# C167Q           0                    0  38.471567 -0.529354       C         Q
# D403A           0                    0        NaN       NaN       D         A
# D403A           0                    0        NaN       NaN       D         A
# D55G            0                    0        NaN       NaN     NaN       NaN
# D55G            0                    0        NaN       NaN     NaN       NaN
# E154D           0                    0  38.699104 -0.688686       E         D
# E154D           0                    0  38.699104 -0.688686       E         D
# E164A           0                    0        NaN       NaN       E         A
# E164A           0                    0        NaN       NaN       E         A
# E177A           0                    0  37.307655 -0.486928       E         A
# E177A           0                    0  37.307655 -0.486928       E         A
# E406D           0                    0  40.554599 -0.926168       E         D
# E406D           0                    0  40.554599 -0.926168       E         D
# E426S           0                    0  39.459240 -1.449480       E         S
# E426S           0                    0  39.459240 -1.449480       E         S
# G174R           0                    0        NaN       NaN     NaN       NaN
# G174R           0                    0        NaN       NaN     NaN       NaN
# G22S            0                    0        NaN       NaN     NaN       NaN
# G22S            0                    0        NaN       NaN     NaN       NaN
# H101R           0                    0  40.021708 -0.910848       H         R
# H101R           0                    0  40.021708 -0.910848       H         R
# H178R           0                    0        NaN       NaN       H         R
# H178R           0                    0        NaN       NaN       H         R
# H223G           0                    0        NaN       NaN     NaN       NaN
# H223G           0                    0        NaN       NaN     NaN       NaN
# H315N           0                    0        NaN       NaN       H         N
# H315N           0                    0        NaN       NaN       H         N
# H328C           0                    0        NaN       NaN     NaN       NaN
# H328C           0                    0        NaN       NaN     NaN       NaN
# ...           ...                  ...        ...       ...     ...       ...
# W120A           0                    0        NaN       NaN       W         A
# W120A           0                    0        NaN       NaN       W         A
# W120F           0                    0  41.510527 -0.462998       W         F
# W120F           0                    0  41.510527 -0.462998       W         F
# W247N           0                    0        NaN       NaN     NaN       NaN
# W247N           0                    0        NaN       NaN     NaN       NaN
# W325L           0                    0  30.523417 -0.135566       W         L
# W325L           0                    0  30.523417 -0.135566       W         L
# W34A            0                    0        NaN       NaN       W         A
# W34A            0                    0        NaN       NaN       W         A
# W399C           0                    0        NaN       NaN       W         C
# W399C           0                    0        NaN       NaN       W         C
# W399S           0                    0        NaN       NaN       W         S
# W399S           0                    0        NaN       NaN       W         S
# W407C           0                    0        NaN       NaN     NaN       NaN
# W407C           0                    0        NaN       NaN     NaN       NaN
# W407G           0                    0  31.738916 -0.140748       W         G
# W407G           0                    0  31.738916 -0.140748       W         G
# W407R           0                    0        NaN       NaN       W         R
# W407R           0                    0        NaN       NaN       W         R
# Y166D           0                    0        NaN       NaN     NaN       NaN
# Y166D           0                    0        NaN       NaN     NaN       NaN
# Y294A           0                    0  39.999766 -0.755361       Y         A
# Y294A           0                    0  39.999766 -0.755361       Y         A
# Y295A           0                    0        NaN       NaN       Y         A
# Y295A           0                    0        NaN       NaN       Y         A
# Y75H            0                    0        NaN       NaN     NaN       NaN
# Y75H            0                    0        NaN       NaN     NaN       NaN
# Y75H            0                    0        NaN       NaN     NaN       NaN
# Y75H            0                    0        NaN       NaN     NaN       NaN
#
#        position
# C167Q       167
# C167Q       167
# D403A       403
# D403A       403
# D55G        NaN
# D55G        NaN
# E154D       154
# E154D       154
# E164A       164
# E164A       164
# E177A       177
# E177A       177
# E406D       406
# E406D       406
# E426S       426
# E426S       426
# G174R       NaN
# G174R       NaN
# G22S        NaN
# G22S        NaN
# H101R       101
# H101R       101
# H178R       178
# H178R       178
# H223G       NaN
# H223G       NaN
# H315N       315
# H315N       315
# H328C       NaN
# H328C       NaN
# ...         ...
# W120A       120
# W120A       120
# W120F       120
# W120F       120
# W247N       NaN
# W247N       NaN
# W325L       325
# W325L       325
# W34A         34
# W34A         34
# W399C       399
# W399C       399
# W399S       399
# W399S       399
# W407C       NaN
# W407C       NaN
# W407G       407
# W407G       407
# W407R       407
# W407R       407
# Y166D       NaN
# Y166D       NaN
# Y294A       294
# Y294A       294
# Y295A       295
# Y295A       295
# Y75H        NaN
# Y75H        NaN
# Y75H        NaN
# Y75H        NaN
#
# [106 rows x 29 columns]

# %%
plt.figure( figsize=( 4, 4 ) )
plt.scatter( joined.tm, joined.total, color='k' )
#plt.plot( ( joined.tm.min(), joined.tm.max() ), ( joined.total.max() , joined.total.min() ), color='red', alpha=0.4 ) #perfect correlation
plt.xlabel( 'Experimental Tm' )
plt.ylabel( 'Predicted ddg' )

# %%
for col, dtype in zip( joined.columns, joined.dtypes ):
    if str( dtype ) == 'float64' and str( col ) not in ['tm', 'k']:
        print col, dtype
        plt.figure( figsize=( 3, 3 ) )
        plt.scatter( joined.tm, joined[col], color='k' )
        #plt.plot( ( joined.tm.min(), joined.tm.max() ), ( joined.total.max() , joined.total.min() ), color='red', alpha=0.4 ) #perfect correlation
        plt.xlabel( 'Experimental Tm' )
        plt.ylabel( col )
        plt.show()
# Out:
# total float64
# fa_atr float64
# fa_rep float64
# fa_sol float64
# fa_intra_rep float64
# fa_elec float64
# pro_close float64
# hbond_sr_bb float64
# hbond_lr_bb float64
# hbond_bb_sc float64
# hbond_sc float64
# dslf_fa13 float64
# coordinate_constraint float64
# angle_constraint float64
# dihedral_constraint float64
# rama float64
# omega float64
# fa_dun float64
# p_aa_pp float64
# ref float64
# chainbreak float64
# res_type_constraint float64
# position float64

# %% [markdown]
# So nothing really correlates, even predicted $\Delta G$ of folding. Bummmer.

# %% [markdown]
# # Rosetta plus machine learning [outperforms `ddg_monomer`?]

# %% [markdown]
# Instead, let's make models of the mutants using `EnzRepackMinimize` and then try to use machine learning to get better correlation.

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import BaggingRegressor
from sklearn.grid_search import GridSearchCV
from glob import glob 

dfs = [ pandas.read_csv( i, sep=r'\s+' ) for i in glob( 'enzdes/out/*sc' ) ]
df = pandas.concat( dfs )
print len( df ), 'models'
df.sample( 10 )
# Out:
# 12863 models
#    total_score  fa_rep  hbond_sc  all_cst  tot_pstat_pm  tot_nlpstat_pm  \
# 0      -631.28  223.88    -71.55     0.01          0.70            0.69
# 0      -181.11  629.05    -71.77     0.01          0.69            0.70
# 0      -624.22  222.96    -70.02     0.01          0.69            0.68
# 0      -625.57  226.28    -71.22     0.01          0.70            0.68
# 0      -628.11  226.65    -70.79     0.00          0.69            0.70
# 0      -626.95  224.46    -71.65     0.00          0.70            0.68
# 0      -623.99  225.78    -72.22     0.00          0.70            0.70
# 0      -627.43  225.51    -72.69     0.00          0.70            0.70
# 0      -629.50  219.65    -68.98     0.00          0.70            0.68
# 0      -628.85  221.00    -72.21     0.01          0.70            0.69
#
#    tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  tot_nlsurfaceE_pm  \
# 0              145           437             147               0.77
# 0              144           440             144               0.62
# 0              144           436             148               1.07
# 0              147           438             150               0.82
# 0              148           436             149               0.77
# 0              147           440             148               0.60
# 0              142           439             149               0.77
# 0              143           438             149               0.90
# 0              149           436             147               0.99
# 0              149           439             148               0.88
#
#           ...           SR_5  SR_5_total_score  SR_5_fa_rep  SR_5_hbond_sc  \
# 0         ...            446             -5.69         0.90          -3.49
# 0         ...            446             -5.35         0.90          -3.25
# 0         ...            446             -4.33         0.78          -2.20
# 0         ...            446             -5.46         0.83          -3.34
# 0         ...            446             -5.71         0.86          -3.21
# 0         ...            446             -5.18         1.07          -3.44
# 0         ...            446             -5.33         0.86          -3.91
# 0         ...            446             -5.88         0.91          -3.94
# 0         ...            446             -4.00         0.90          -2.31
# 0         ...            446             -5.38         0.77          -3.39
#
#    SR_5_all_cst  SR_5_interf_E_1_2  SR_5_dsasa_1_2  SR_5_hbond_pm  \
# 0          0.00             -11.39            0.90              7
# 0          0.00             -10.70            0.90              7
# 0          0.01              -8.66            0.90              5
# 0          0.00             -10.92            0.93              7
# 0          0.00             -11.42            0.91              7
# 0          0.00             -10.35            0.89              7
# 0          0.00             -10.65            0.89              8
# 0          0.00             -11.75            0.90              8
# 0          0.00              -7.99            0.90              6
# 0          0.01             -10.76            0.90              7
#
#    SR_5_burunsat_pm          description
# 0                 1  bglb_163ALA_73_0001
# 0                 1  bglb_101ARG_74_0001
# 0                 1  bglb_407ALA_83_0001
# 0                 1  bglb_222GLN_19_0001
# 0                 1  bglb_220HIS_12_0001
# 0                 1  bglb_178ALA_58_0001
# 0                 1  bglb_325HIS_79_0001
# 0                 1  bglb_404ALA_33_0001
# 0                 1  bglb_120ALA_40_0001
# 0                 1  bglb_407LYS_19_0001
#
# [10 rows x 60 columns]

# %%
from Bio.SeqUtils import IUPACData
import screed

for record in screed.open( 'data/bglb.pep' ):
    seq = record.sequence

# blarg, we have to reindex the DataFrame because of how I named the Rosetta output
l = []
for i in df.description:
    j = i.split( '_' )[1]
    pos = j[:-3]
    native = seq[ int(pos) - 1 ].upper()
    designed = IUPACData.protein_letters_3to1[ j[-3:].capitalize() ] # good god why
    l.append( '{}{}{}'.format( native, pos, designed ) )
df['name'] = l

# %%
df.head( 20 )
# Out:
#    total_score  fa_rep  hbond_sc  all_cst  tot_pstat_pm  tot_nlpstat_pm  \
# 0      -621.52  227.68    -71.56     0.01          0.70            0.68
# 0      -625.44  223.92    -74.89     0.01          0.69            0.69
# 0      -623.50  227.11    -71.43     0.00          0.71            0.69
# 0      -612.03  225.36    -66.07     0.00          0.70            0.68
# 0      -620.22  226.81    -69.18     0.00          0.69            0.69
# 0      -626.34  225.29    -73.66     0.01          0.68            0.67
# 0      -630.24  225.53    -73.43     0.00          0.71            0.70
# 0      -630.54  225.68    -74.10     0.01          0.70            0.70
# 0      -629.84  224.86    -72.00     0.01          0.71            0.70
# 0      -555.96  277.82    -70.43     0.00          0.70            0.69
# 0      -623.40  227.10    -72.13     0.00          0.70            0.70
# 0      -629.05  226.77    -74.36     0.00          0.68            0.69
# 0      -628.26  223.94    -69.45     0.01          0.69            0.70
# 0      -632.08  225.16    -72.30     0.00          0.71            0.70
# 0      -624.87  226.48    -72.59     0.00          0.70            0.71
# 0      -629.63  223.13    -75.21     0.01          0.69            0.69
# 0      -629.68  224.59    -73.10     0.01          0.71            0.69
# 0      -617.75  227.18    -70.73     0.00          0.70            0.69
# 0      -626.91  222.45    -70.77     0.00          0.70            0.70
# 0      -619.07  227.40    -73.14     0.00          0.70            0.69
#
#    tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  tot_nlsurfaceE_pm  ...    \
# 0              145           438             150               0.67  ...
# 0              140           439             148               0.67  ...
# 0              148           437             150               0.99  ...
# 0              148           433             146               0.99  ...
# 0              149           435             147               0.65  ...
# 0              144           439             147               0.65  ...
# 0              137           440             149               0.72  ...
# 0              141           439             151               0.77  ...
# 0              143           439             149               0.75  ...
# 0              154           433             143               0.77  ...
# 0              145           438             150               0.60  ...
# 0              144           438             151               0.82  ...
# 0              146           436             149               0.70  ...
# 0              144           440             145               0.77  ...
# 0              141           441             149               0.80  ...
# 0              134           442             152               1.16  ...
# 0              142           440             148               0.60  ...
# 0              147           439             149               0.70  ...
# 0              146           437             145               0.68  ...
# 0              145           438             151               0.69  ...
#
#    SR_5_total_score  SR_5_fa_rep  SR_5_hbond_sc  SR_5_all_cst  \
# 0             -5.45         0.95          -3.62          0.00
# 0             -6.42         0.77          -4.23          0.00
# 0             -5.75         0.89          -4.01          0.00
# 0             -3.54         1.09          -1.78          0.00
# 0             -5.06         0.85          -3.14          0.00
# 0             -5.93         0.89          -4.03          0.00
# 0             -5.96         0.93          -3.98          0.00
# 0             -5.96         0.92          -4.07          0.01
# 0             -5.18         1.09          -3.47          0.00
# 0             -5.70         1.12          -3.98          0.00
# 0             -5.65         0.84          -3.81          0.00
# 0             -5.91         0.80          -3.93          0.00
# 0             -4.34         0.90          -2.82          0.00
# 0             -5.84         0.92          -3.99          0.00
# 0             -5.71         0.82          -4.03          0.00
# 0             -5.80         1.00          -4.11          0.00
# 0             -6.10         1.14          -3.68          0.00
# 0             -4.96         0.98          -3.08          0.00
# 0             -5.15         0.87          -3.36          0.00
# 0             -5.68         0.85          -3.58          0.00
#
#    SR_5_interf_E_1_2  SR_5_dsasa_1_2  SR_5_hbond_pm  SR_5_burunsat_pm  \
# 0             -10.91            0.90              8                 1
# 0             -12.84            0.91              8                 1
# 0             -11.49            0.93              8                 1
# 0              -7.08            0.91              4                 2
# 0             -10.12            0.91              7                 1
# 0             -11.85            0.90              8                 1
# 0             -11.92            0.90              8                 1
# 0             -11.92            0.91              8                 1
# 0             -10.36            0.90              7                 1
# 0             -11.41            0.90              8                 1
# 0             -11.31            0.90              8                 1
# 0             -11.82            0.91              8                 1
# 0              -8.68            0.91              6                 1
# 0             -11.67            0.91              8                 1
# 0             -11.42            0.90              8                 1
# 0             -11.60            0.90              8                 0
# 0             -12.19            0.93              8                 1
# 0              -9.91            0.89              7                 0
# 0             -10.31            0.88              7                 1
# 0             -11.36            0.90              7                 1
#
#            description   name
# 0  bglb_219ALA_98_0001  L219A
# 0   bglb_34ALA_59_0001   W34A
# 0  bglb_240LYS_15_0001  R240K
# 0  bglb_407ALA_62_0001  W407A
# 0  bglb_407TYR_24_0001  W407Y
# 0   bglb_72ALA_49_0001   F72A
# 0  bglb_404ALA_44_0001  N404A
# 0   bglb_52GLY_55_0001   V52G
# 0  bglb_315ASN_66_0001  H315N
# 0  bglb_32LEU_100_0001   S32L
# 0  bglb_147SER_11_0001  V147S
# 0  bglb_413ALA_68_0001  K413A
# 0  bglb_406ASP_90_0001  E406D
# 0  bglb_294PHE_51_0001  Y294F
# 0  bglb_323LYS_71_0001  M323K
# 0  bglb_415ALA_24_0001  F415A
# 0  bglb_171ARG_54_0001  L171R
# 0  bglb_323GLY_81_0001  M323G
# 0  bglb_399GLY_34_0001  W399G
# 0  bglb_244GLU_68_0001  I244E
#
# [20 rows x 61 columns]

# %%
# get lowest 10% energy by total_score 
def low_10( df ):
    return df.sort( 'total_score' ).head( 10 )

df = df.groupby( 'name' ).apply( low_10 )
df.head( 20 )
# Out:
#          total_score   fa_rep  hbond_sc  all_cst  tot_pstat_pm  \
# name
# A192S 0      -634.39   222.81    -73.18     0.01          0.69
#       0      -633.78   223.71    -74.49     0.01          0.71
#       0      -633.67   225.06    -73.63     0.01          0.71
#       0      -633.65   223.75    -73.68     0.00          0.70
#       0      -633.53   223.72    -74.34     0.00          0.70
#       0      -632.89   224.81    -73.80     0.01          0.68
#       0      -632.73   223.95    -74.97     0.01          0.70
#       0      -632.35   224.53    -74.38     0.01          0.68
#       0      -631.77   226.00    -73.49     0.00          0.70
#       0      -631.41   224.67    -76.32     0.01          0.70
# A227W 0      5150.70  5996.03    -73.48     0.00          0.69
#       0      5150.79  5996.62    -73.39     0.00          0.69
#       0      5151.43  5997.01    -72.07     0.00          0.70
#       0      5152.47  5997.75    -73.01     0.00          0.69
#       0      5152.83  5997.39    -73.05     0.00          0.71
#       0      5152.85  5997.00    -73.13     0.00          0.69
#       0      5153.26  5996.45    -74.42     0.00          0.69
#       0      5153.54  5997.27    -72.26     0.00          0.69
#       0      5153.68  5997.56    -72.55     0.00          0.70
#       0      5154.22  5997.39    -72.74     0.01          0.71
#
#          tot_nlpstat_pm  tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  \
# name
# A192S 0            0.68              141           438             148
#       0            0.69              142           441             150
#       0            0.69              146           438             150
#       0            0.70              145           439             149
#       0            0.69              142           441             153
#       0            0.69              143           441             147
#       0            0.69              138           441             151
#       0            0.70              142           440             151
#       0            0.70              141           441             149
#       0            0.69              141           439             152
# A227W 0            0.69              141           440             150
#       0            0.69              144           440             151
#       0            0.70              147           438             148
#       0            0.70              146           439             150
#       0            0.70              143           438             149
#       0            0.68              144           440             150
#       0            0.70              146           439             149
#       0            0.68              146           438             150
#       0            0.69              146           439             150
#       0            0.70              145           440             152
#
#          tot_nlsurfaceE_pm  ...    SR_5_total_score  SR_5_fa_rep  \
# name                        ...
# A192S 0               0.65  ...               -5.78         0.86
#       0               0.82  ...               -5.80         1.00
#       0               0.82  ...               -5.33         0.94
#       0               0.82  ...               -5.42         0.88
#       0               0.58  ...               -5.87         0.93
#       0               0.60  ...               -5.35         0.91
#       0               0.82  ...               -5.82         0.93
#       0               0.65  ...               -5.75         0.99
#       0               0.69  ...               -5.42         0.81
#       0               0.65  ...               -6.13         0.87
# A227W 0               0.84  ...               -6.01         0.90
#       0               0.89  ...               -5.91         0.94
#       0               0.72  ...               -5.34         0.91
#       0               0.65  ...               -6.03         0.84
#       0               0.89  ...               -5.80         0.95
#       0               0.89  ...               -5.87         0.94
#       0               0.84  ...               -5.73         0.91
#       0               0.89  ...               -5.70         0.88
#       0               0.89  ...               -5.09         0.87
#       0               0.89  ...               -6.01         0.89
#
#          SR_5_hbond_sc  SR_5_all_cst  SR_5_interf_E_1_2  SR_5_dsasa_1_2  \
# name
# A192S 0          -3.58          0.00             -11.56            0.90
#       0          -3.99          0.00             -11.61            0.90
#       0          -3.22          0.00             -10.65            0.90
#       0          -3.30          0.00             -10.83            0.90
#       0          -4.05          0.00             -11.75            0.90
#       0          -3.27          0.00             -10.70            0.89
#       0          -3.99          0.00             -11.64            0.91
#       0          -3.96          0.00             -11.49            0.90
#       0          -3.27          0.00             -10.83            0.90
#       0          -4.13          0.01             -12.25            0.90
# A227W 0          -4.09          0.00             -12.02            0.90
#       0          -4.09          0.00             -11.83            0.90
#       0          -3.23          0.00             -10.68            0.90
#       0          -4.12          0.00             -12.06            0.90
#       0          -3.97          0.00             -11.60            0.91
#       0          -4.01          0.00             -11.73            0.90
#       0          -3.90          0.00             -11.46            0.91
#       0          -3.91          0.00             -11.40            0.90
#       0          -3.06          0.00             -10.18            0.90
#       0          -4.06          0.00             -12.01            0.90
#
#          SR_5_hbond_pm  SR_5_burunsat_pm          description   name
# name
# A192S 0              7                 1  bglb_192SER_81_0001  A192S
#       0              8                 1  bglb_192SER_68_0001  A192S
#       0              7                 1  bglb_192SER_58_0001  A192S
#       0              7                 1  bglb_192SER_14_0001  A192S
#       0              8                 1  bglb_192SER_49_0001  A192S
#       0              7                 1  bglb_192SER_78_0001  A192S
#       0              8                 1  bglb_192SER_13_0001  A192S
#       0              8                 1  bglb_192SER_57_0001  A192S
#       0              7                 1  bglb_192SER_54_0001  A192S
#       0              8                 1   bglb_192SER_3_0001  A192S
# A227W 0              8                 1  bglb_227TRP_68_0001  A227W
#       0              8                 1  bglb_227TRP_54_0001  A227W
#       0              7                 1  bglb_227TRP_11_0001  A227W
#       0              8                 1  bglb_227TRP_58_0001  A227W
#       0              8                 1  bglb_227TRP_97_0001  A227W
#       0              8                 1  bglb_227TRP_86_0001  A227W
#       0              8                 1  bglb_227TRP_32_0001  A227W
#       0              8                 1  bglb_227TRP_43_0001  A227W
#       0              7                 1  bglb_227TRP_42_0001  A227W
#       0              8                 1  bglb_227TRP_31_0001  A227W
#
# [20 rows x 61 columns]

# %%
# reindex and join with experimental data 
df.index = df.name 
joined = df.join( fits )
joined.sample( 10 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f78c9a6a63d4> in <module>()
#       1 # reindex and join with experimental data
# ----> 2 df.index = df.name
#       3 joined = df.join( fits )
#       4 joined.sample( 10 )
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
# diagnostics and droping NaN values 
print len( joined )
joined.dropna( inplace = True )
print len( joined ), 'models'

# clean up data for sklearn
x_cols = [ u'total_score', u'fa_rep', u'hbond_sc', u'tot_pstat_pm',
       u'tot_nlpstat_pm', u'tot_burunsat_pm', u'tot_hbond_pm',
       u'tot_NLconts_pm', u'tot_nlsurfaceE_pm', u'tot_total_charge',
       u'tot_total_pos_charges', u'tot_total_neg_charges', u'tot_seq_recovery',
       u'SR_1_total_score', u'SR_1_fa_rep', u'SR_1_hbond_sc',
       u'SR_1_hbond_pm', u'SR_1_burunsat_pm',
       u'SR_1_pstat_pm', u'SR_1_nlpstat_pm', u'SR_2_total_score',
       u'SR_2_fa_rep', u'SR_2_hbond_sc', u'SR_2_all_cst', u'SR_2_hbond_pm',
       u'SR_2_burunsat_pm', u'SR_2_pstat_pm', u'SR_2_nlpstat_pm',
       u'SR_3_total_score', u'SR_3_fa_rep', u'SR_3_hbond_sc', 
       u'SR_3_hbond_pm', u'SR_3_burunsat_pm', u'SR_3_pstat_pm',
       u'SR_3_nlpstat_pm', u'SR_4_total_score', u'SR_4_fa_rep',
       u'SR_4_hbond_sc', u'SR_4_hbond_pm',
       u'SR_4_burunsat_pm', u'SR_4_pstat_pm', u'SR_4_nlpstat_pm',
       u'SR_5_total_score', u'SR_5_fa_rep', u'SR_5_hbond_sc', u'SR_5_all_cst',
       u'SR_5_interf_E_1_2', u'SR_5_dsasa_1_2', u'SR_5_hbond_pm',
       u'SR_5_burunsat_pm', ]

X = joined[ x_cols ]
y = joined[ 'tm' ]
# Out:
# 1250
# 460 models

# %% [markdown]
# Now we actually fit the data to the model

# %%
params = { 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1] }

from sklearn.cross_validation import StratifiedKFold
from scipy.stats.stats import pearsonr

for i in [ 1, 10, 100, 1000 ]:
    #skf = StratifiedKFold( y, 10 )
    net = ElasticNetCV( cv=10 )
    grid = GridSearchCV( net, params )
    bag = BaggingRegressor( grid, n_estimators=i )
    bag.fit( X, y )

    preds = bag.predict( X )
    print 'Number of models', i 
    print 'PCC={}'.format( pearsonr( preds, y ) )

    plt.figure( figsize=(4,4) )
    plt.scatter( preds, y, alpha=0.3, marker='.', color='k' )
    plt.xlabel( 'Predicted' )
    plt.ylabel( 'Actual' )
    plt.show()
    
    weights = pandas.DataFrame( zip( X.columns, bag.estimators_[0].best_estimator_.coef_ ), columns=['feature', 'weight'] )
    print weights.sort( 'weight' )[0:11]
# Out:
# Number of models 1
# PCC=(0.52514131969539968, 5.7517792467570399e-34)
# /home/carlin/bin/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:444: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)

# %% [markdown]
# So that's fairly underwhelming. Let's try something else.
#
# ## Structures minimized with `ddg_monomer` scored using EnzDes-style metrics

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import BaggingRegressor
from sklearn.grid_search import GridSearchCV
from glob import glob 


df = pandas.read_csv( 'enzdes_score_ddg/out/score.sc', sep='\s+' )
print len( df ), 'models'
df.sample( 10 )

# # reindex and join with experimental data 
# df.index = df.name 
# joined = df.join( fits )
# joined.sample( 10 )

# # diagnostics and droping NaN values 
# print len( joined )
# joined.dropna( inplace = True )
# print len( joined ), 'models'

# # clean up data for sklearn
# x_cols = [ u'total_score', u'fa_rep', u'hbond_sc', u'tot_pstat_pm',
#        u'tot_nlpstat_pm', u'tot_burunsat_pm', u'tot_hbond_pm',
#        u'tot_NLconts_pm', u'tot_nlsurfaceE_pm', u'tot_total_charge',
#        u'tot_total_pos_charges', u'tot_total_neg_charges', u'tot_seq_recovery',
#        u'SR_1_total_score', u'SR_1_fa_rep', u'SR_1_hbond_sc',
#        u'SR_1_hbond_pm', u'SR_1_burunsat_pm',
#        u'SR_1_pstat_pm', u'SR_1_nlpstat_pm', u'SR_2_total_score',
#        u'SR_2_fa_rep', u'SR_2_hbond_sc', u'SR_2_all_cst', u'SR_2_hbond_pm',
#        u'SR_2_burunsat_pm', u'SR_2_pstat_pm', u'SR_2_nlpstat_pm',
#        u'SR_3_total_score', u'SR_3_fa_rep', u'SR_3_hbond_sc', 
#        u'SR_3_hbond_pm', u'SR_3_burunsat_pm', u'SR_3_pstat_pm',
#        u'SR_3_nlpstat_pm', u'SR_4_total_score', u'SR_4_fa_rep',
#        u'SR_4_hbond_sc', u'SR_4_hbond_pm',
#        u'SR_4_burunsat_pm', u'SR_4_pstat_pm', u'SR_4_nlpstat_pm',
#        u'SR_5_total_score', u'SR_5_fa_rep', u'SR_5_hbond_sc', u'SR_5_all_cst',
#        u'SR_5_interf_E_1_2', u'SR_5_dsasa_1_2', u'SR_5_hbond_pm',
#        u'SR_5_burunsat_pm', ]

# X = joined[ x_cols ]
# y = joined[ 'tm' ]

# params = { 'l1_ratio': [.1, .5, .7, .9, .95, .99, 1] }

# from sklearn.cross_validation import StratifiedKFold
# from scipy.stats.stats import pearsonr

# for i in [ 1, 10, 100, 1000 ]:
#     #skf = StratifiedKFold( y, 10 )
#     net = ElasticNetCV( cv=10 )
#     grid = GridSearchCV( net, params )
#     bag = BaggingRegressor( grid, n_estimators=i )
#     bag.fit( X, y )

#     preds = bag.predict( X )
#     print 'Number of models', i 
#     print 'PCC={}'.format( pearsonr( preds, y ) )

#     plt.figure( figsize=(4,4) )
#     plt.scatter( preds, y, alpha=0.3, marker='.', color='k' )
#     plt.xlabel( 'Predicted' )
#     plt.ylabel( 'Actual' )
#     plt.show()
    
#     weights = pandas.DataFrame( zip( X.columns, bag.estimators_[0].best_estimator_.coef_ ), columns=['feature', 'weight'] )
#     print weights.sort( 'weight' )[0:11]

# %% [markdown]
# ## Individual plots for W120F and N407C
#
# As per Siena's request Sunday, March 20

# %%
import pandas 

df = pandas.read_csv( '/Users/alex/Downloads/Bagel Thermostability - Best Mutants.csv' )
grouped = df.groupby( [ 'mutant', 'trial' ] )

for i, df in grouped:
    df.rate = df.rate / df.rate.max()

    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]

    p0 = ( df.temp.mean(), slope )
    popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
    perr = sqrt( diag( pcov ) ) 

    plt.figure()
    plt.xlabel( 'T (C)' )
    plt.xlim( 25, 55 )
    plt.scatter( df.temp, df.rate )
    xs = linspace( df.temp.min(), df.temp.max(), 100 )
    plt.plot( xs, f( xs, *popt ) )
    wts = linspace( 30, 50, 100 )
    plt.plot( wts, f( wts, 39.88, -1.12 ) ) 
    plt.legend( [ i, 'Wild type BglB'] )
    plt.text( 30, 0.2, 'Tm = {:2.1f} C'.format( popt[0] ), size=12 )
    plt.text( 30, 0, 'k = {:2.2f}'.format( popt[1] ), size=12 )
    plt.show()

# %%
import pandas 

df = pandas.read_csv( '/Users/alex/Downloads/Bagel Thermostability - Best Mutants.csv' )
grouped = df.groupby( [ 'mutant' ] )

for i, df in grouped:
    df.rate = df.rate / df.rate.max()

    # linear fit 
    reg = LinearRegression()
    reg.fit( df.temp.reshape(-1, 1), df.rate )
    slope = reg.coef_[0]

    p0 = ( df.temp.mean(), slope )
    popt, pcov = curve_fit( f, df.temp, df.rate, p0=p0 )
    perr = sqrt( diag( pcov ) ) 

    plt.figure()
    plt.xlabel( 'T (C)' )
    plt.xlim( 25, 55 )
    plt.scatter( df.temp, df.rate )
    xs = linspace( df.temp.min(), df.temp.max(), 100 )
    plt.plot( xs, f( xs, *popt ) )
    wts = linspace( 30, 50, 100 )
    plt.plot( wts, f( wts, 39.88, -1.12 ) ) 
    plt.legend( [ i, 'Wild type BglB'] )
    plt.text( 30, 0.2, 'Tm = {:2.1f} C'.format( popt[0] ), size=12 )
    plt.text( 30, 0, 'k = {:2.2f}'.format( popt[1] ), size=12 )
    plt.show()

# %% [markdown]
# ## Production and purification data

# %%
df = pandas.read_csv( 'data/Bagel Thermostability - Thermostability protein production progress.csv', index_col='mutant' )
